# f8aa47cfc504e83f6359fe60172ccb98c40c7da4          GenzDiscontinuous2  334
# f8e13afe72ac12642541c894713f0ad0d4d18fb0                      Kink2D  202
# f8e13afe72ac12642541c894713f0ad0d4d18fb0                      Kink2D  191
# fc68ffb6062871989ebcccb5a707cbf1a385aaf5            GenzOscillatory5  284
# fcda99d313908980f6584745a38dd83705bc5284             GenzContinuous2  250
# fde1cb28d0adef796e89e62d2aa37c41fc383c35                  SingleStep  309
# fe7a674f4691a48e26b51e12c8c2531e27e8e368                 SPXOptions4  918
# fe7a674f4691a48e26b51e12c8c2531e27e8e368                 SPXOptions4  830
# ff136ddbb4ba2309328de77b3901aed0bce24dd9             GenzContinuous2  703
# ffbccd0569e6ba74efc31c88f043b89079e723b3            GenzOscillatory5  260
#
#                                                                  model model2  \
# exp_hash
# 00cc618a793e3dc4332b5cdb5a3be2cc66a00af8                 N<DKLGPModel>   None
# 00cc618a793e3dc4332b5cdb5a3be2cc66a00af8                 N<DKLGPModel>   None
# 01a472c69d6536af485c1e1ac6d1e61123cd6236                    DKLGPModel   None
# 01dc4d606ca69b71b4ee3cf0e1583f7a17ce6a0f                    DKLGPModel   None
# 025faffa02580123bdcbdd52ec8255b24f771336                    N<GPModel>   None
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab            AdaptiveSparseGrid   None
# 03d6c0ac821199da01b776e268cd6aaee634bc2a                 N<DKLGPModel>   None
# 066baaf72daea88c307aa2581a2a47e1880b4bba                    DKLGPModel   None
# 0693cdabc2bedf85874f4b2eb6e08d7fdc01b4c5                 N<DKLGPModel>   None
# 06abe85607dcdeecff6305a5a76512d83c1d4028                 N<DKLGPModel>   None
# 06abe85607dcdeecff6305a5a76512d83c1d4028                 N<DKLGPModel>   None
# 08c0c5fd95eadcb6476b5781fb0ae1e27895af74                    DKLGPModel   None
# 0b9267878902e0421b587e3670ac9c7051eed871                 N<DKLGPModel>   None
# 0b9267878902e0421b587e3670ac9c7051eed871                 N<DKLGPModel>   None
# 0b9267878902e0421b587e3670ac9c7051eed871                 N<DKLGPModel>   None
# 0bade9985253116a56cd7fe2499897d042fc446b                 N<DKLGPModel>   None
# 0c6422ebe3f59d8416d731b0269d956c3338de45                    DKLGPModel   None
# 0d1d64f25a7f6ce3ed42e06f927e42876c18aac3                          SSGP   None
# 0db04835ac2edd9d54baf7f84c789c33fc7110e0                 N<DKLGPModel>   None
# 0e0f47c0680a088c894d2e40e140d51090ea45a7  T<ActiveSubspace,DKLGPModel>   None
# 0e0f47c0680a088c894d2e40e140d51090ea45a7  T<ActiveSubspace,DKLGPModel>   None
# 0e368339b59175bcb56073633abe8f27d4414bf0                    DKLGPModel   None
# 0efc34fd02f4f9d67bdb9970e9b9858c3f41161a                 N<DKLGPModel>   None
# 0f40fc8ee4a72f4a62acd4b0b9a92cf646c61e18  T<ActiveSubspace,DKLGPModel>   None
# 0f40fc8ee4a72f4a62acd4b0b9a92cf646c61e18  T<ActiveSubspace,DKLGPModel>   None
# 0faa23c93f0b49d06e7f668ab7d4690ee4fb0013                 N<DKLGPModel>   None
# 0faa23c93f0b49d06e7f668ab7d4690ee4fb0013                 N<DKLGPModel>   None
# 10272ceb7128a90ce5c4208938551cca503ebeb6                    DKLGPModel   None
# 11b7b91dc1b7980682eb36e47f0b6c2a59740cc0                 N<DKLGPModel>   None
# 11b7b91dc1b7980682eb36e47f0b6c2a59740cc0                 N<DKLGPModel>   None
# ...                                                                ...    ...
# e2f04ecf1d8d741852eaac7ef6139891b368b88a            AdaptiveSparseGrid   None
# e30adb5af13213e3b2c79689ecad62e6853d1c94                 N<DKLGPModel>   None
# e36ed0fe33aa63287899063a0a668b2d8b198f56                 N<DKLGPModel>   None
# e3cba4f54f804acd0e36c2df41c35cb7fd236f9e                    DKLGPModel   None
# e48aa2ed6310a413c9fe976d02f6884b59ac0640                    DKLGPModel   None
# e55010bceb660e048defb46e8f9325b6c5250852                    DKLGPModel   None
# e59a23471b2ffc862e7e648e4ae3f56f2c22fab3                    DKLGPModel   None
# e5d6512c9be08be28818c02c53df67c3c866d88e                    DKLGPModel   None
# e893252143aeff950f654ce9bfd5d2e4aa8cd38b                 N<DKLGPModel>   None
# e9c1a3e6d5b8880e3f7324dd11ddcc145e16f0bc                    DKLGPModel   None
# e9c1a3e6d5b8880e3f7324dd11ddcc145e16f0bc                    DKLGPModel   None
# ea569837d4b9b0e4da6c98ce0c8d21c10362a22c                    N<GPModel>   None
# f0b84beb2dec929337180991c621e0edbd6458a7                 N<DKLGPModel>   None
# f119ff66cfcfb7e476aba3918d54eb2b71802d01                 N<DKLGPModel>   None
# f1f851b2239a1d821f5f816fdd8aa2d8f4d9d7ff            AdaptiveSparseGrid   None
# f37cd113a46ec44ee48150426a2d923a23fd44b8                    DKLGPModel   None
# f4143a190159caba8e4d622868dddcfa77a96b62                 N<DKLGPModel>   None
# f673cea7ad470d4692631aefadbe083c440e84a1                 N<DKLGPModel>   None
# f6ad0cad4503f74565b7a06af6704718b3aed19d  T<ActiveSubspace,DKLGPModel>   None
# f6ad0cad4503f74565b7a06af6704718b3aed19d  T<ActiveSubspace,DKLGPModel>   None
# f8aa47cfc504e83f6359fe60172ccb98c40c7da
# 08c0c5fd95eadcb6476b5781fb0ae1e27895af74                     DKLGPModel GenzProductPeak10
# 0b9267878902e0421b587e3670ac9c7051eed871                    N<DKLGPModel> GenzContinuous2
# 0b9267878902e0421b587e3670ac9c7051eed871                    N<DKLGPModel> GenzContinuous2
# 0b9267878902e0421b587e3670ac9c7051eed871                    N<DKLGPModel> GenzContinuous2
# 0bade9985253116a56cd7fe2499897d042fc446b                    N<DKLGPModel> GenzCornerPeak2
# 0c6422ebe3f59d8416d731b0269d956c3338de45                            DKLGPModel SingleStep
# 0d1d64f25a7f6ce3ed42e06f927e42876c18aac3                                        SSGP Sinc
# 0db04835ac2edd9d54baf7f84c789c33fc7110e0         N<DKLGPModel> ActiveSubspaceArbitrary1D5
# 0e0f47c0680a088c894d2e40e140d51090ea45a7              T<ActiveSubspace,DKLGPModel> Kink2D
# 0e0f47c0680a088c894d2e40e140d51090ea45a7              T<ActiveSubspace,DKLGPModel> Kink2D
# 0e368339b59175bcb56073633abe8f27d4414bf0                            DKLGPModel SingleStep
# 0efc34fd02f4f9d67bdb9970e9b9858c3f41161a                 N<DKLGPModel> GenzDiscontinuous2
# 0f40fc8ee4a72f4a62acd4b0b9a92cf646c61e18  T<ActiveSubspace,DKLGPModel> ActiveSubspaceTest
# 0f40fc8ee4a72f4a62acd4b0b9a92cf646c61e18  T<ActiveSubspace,DKLGPModel> ActiveSubspaceTest
# 0faa23c93f0b49d06e7f668ab7d4690ee4fb0013                        N<DKLGPModel> SPXOptions3
# 0faa23c93f0b49d06e7f668ab7d4690ee4fb0013                        N<DKLGPModel> SPXOptions3
# 10272ceb7128a90ce5c4208938551cca503ebeb6                     DKLGPModel GenzGaussianPeak2
# 11b7b91dc1b7980682eb36e47f0b6c2a59740cc0                        N<DKLGPModel> SPXOptions4
# 11b7b91dc1b7980682eb36e47f0b6c2a59740cc0                        N<DKLGPModel> SPXOptions4
# ...                                                                                   ...
# e2f04ecf1d8d741852eaac7ef6139891b368b88a            AdaptiveSparseGrid HestonOptionPricer
# e30adb5af13213e3b2c79689ecad62e6853d1c94                   N<DKLGPModel> GenzOscillatory2
# e36ed0fe33aa63287899063a0a668b2d8b198f56                    N<DKLGPModel> GenzContinuous2
# e3cba4f54f804acd0e36c2df41c35cb7fd236f9e                    DKLGPModel GenzGaussianPeak50
# e48aa2ed6310a413c9fe976d02f6884b59ac0640                      DKLGPModel GenzCornerPeak50
# e55010bceb660e048defb46e8f9325b6c5250852                            DKLGPModel SingleStep
# e59a23471b2ffc862e7e648e4ae3f56f2c22fab3                            DKLGPModel SingleStep
# e5d6512c9be08be28818c02c53df67c3c866d88e                     DKLGPModel GenzProductPeak10
# e893252143aeff950f654ce9bfd5d2e4aa8cd38b                        N<DKLGPModel> SPXOptions3
# e9c1a3e6d5b8880e3f7324dd11ddcc145e16f0bc                                  DKLGPModel Step
# e9c1a3e6d5b8880e3f7324dd11ddcc145e16f0bc                                  DKLGPModel Step
# ea569837d4b9b0e4da6c98ce0c8d21c10362a22c                                N<GPModel> Branin
# f0b84beb2dec929337180991c621e0edbd6458a7                        N<DKLGPModel> SPXOptions1
# f119ff66cfcfb7e476aba3918d54eb2b71802d01                        N<DKLGPModel> SPXOptions1
# f1f851b2239a1d821f5f816fdd8aa2d8f4d9d7ff            AdaptiveSparseGrid HestonOptionPricer
# f37cd113a46ec44ee48150426a2d923a23fd44b8                      DKLGPModel GenzCornerPeak50
# f4143a190159caba8e4d622868dddcfa77a96b62                 N<DKLGPModel> HestonOptionPricer
# f673cea7ad470d4692631aefadbe083c440e84a1                 N<DKLGPModel> HestonOptionPricer
# f6ad0cad4503f74565b7a06af6704718b3aed19d   T<ActiveSubspace,DKLGPModel> TwoKinkDEmbedding
# f6ad0cad4503f74565b7a06af6704718b3aed19d   T<ActiveSubspace,DKLGPModel> TwoKinkDEmbedding
# f8aa47cfc504e83f6359fe60172ccb98c40c7da4                 N<DKLGPModel> GenzDiscontinuous2
# f8e13afe72ac12642541c894713f0ad0d4d18fb0                 T<ActiveSubspace,GPModel> Kink2D
# f8e13afe72ac12642541c894713f0ad0d4d18fb0                 T<ActiveSubspace,GPModel> Kink2D
# fc68ffb6062871989ebcccb5a707cbf1a385aaf5                      DKLGPModel GenzOscillatory5
# fcda99d313908980f6584745a38dd83705bc5284                       DKLGPModel GenzContinuous2
# fde1cb28d0adef796e89e62d2aa37c41fc383c35
# e9c1a3e6d5b8880e3f7324dd11ddcc145e16f0bc                            step
# e9c1a3e6d5b8880e3f7324dd11ddcc145e16f0bc                            step
# ea569837d4b9b0e4da6c98ce0c8d21c10362a22c  scalability-finding-functionsM
# f0b84beb2dec929337180991c621e0edbd6458a7                         default
# f119ff66cfcfb7e476aba3918d54eb2b71802d01                      SPXOptions
# f1f851b2239a1d821f5f816fdd8aa2d8f4d9d7ff                          heston
# f37cd113a46ec44ee48150426a2d923a23fd44b8                            genz
# f4143a190159caba8e4d622868dddcfa77a96b62                          heston
# f673cea7ad470d4692631aefadbe083c440e84a1                          heston
# f6ad0cad4503f74565b7a06af6704718b3aed19d                       embedding
# f6ad0cad4503f74565b7a06af6704718b3aed19d                       embedding
# f8aa47cfc504e83f6359fe60172ccb98c40c7da4              genz-dkl-normalize
# f8e13afe72ac12642541c894713f0ad0d4d18fb0                       embedding
# f8e13afe72ac12642541c894713f0ad0d4d18fb0                       embedding
# fc68ffb6062871989ebcccb5a707cbf1a385aaf5                            genz
# fcda99d313908980f6584745a38dd83705bc5284                            genz
# fde1cb28d0adef796e89e62d2aa37c41fc383c35                            step
# fe7a674f4691a48e26b51e12c8c2531e27e8e368                      SPXOptions
# fe7a674f4691a48e26b51e12c8c2531e27e8e368                         default
# ff136ddbb4ba2309328de77b3901aed0bce24dd9             scalability-fixed-M
# ffbccd0569e6ba74efc31c88f043b89079e723b3                            genz
#
# [361 rows x 18 columns]

# %% [markdown]
# # High-dim

# %% [markdown]
# ## Real world

# %% [markdown]
# # Scalability

# %% [markdown]
# ## UCI

# %% [markdown]
# - find out what M we can pick for other experiments (high-dim)

# %% [markdown]
# ### Create

# %%
# Both are 3 dim so pick M accordingly
Ms = [25, 40, 60]

for M in Ms:
    for name in ['3droad', 'tamielectric']:
        run = execute(config_updates={
            'tag': 'uci',
            'obj_func': {
                'name': 'UCI',
                'kwargs': {'name': name},
            },
            'model': {
                'name': 'DKLGPModel',
                'kwargs': {
                    'learning_rate': 0.1,
                    'n_iter': 10,
                    'nn_kwargs': {'layers': None},
                    'gp_kwargs': {'n_grid': M},
                    'max_cg_iter': 1000,
                    'precond_size': 10,
                    'use_cg': True,
                    'noise': None
                }
            },
        })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="uci"\' \'obj_func={"name": "UCI", "kwargs": {"name": "3droad"}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 10, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 25}, "max_cg_iter": 1000, "precond_size": 10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="uci"\' \'obj_func={"name": "UCI", "kwargs": {"name": "tamielectric"}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 10, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 25}, "max_cg_iter": 1000, "precond_size": 10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="uci"\' \'obj_func={"name": "UCI", "kwargs": {"name": "3droad"}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 10, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 40}, "max_cg_iter": 1000, "precond_size": 10, "use_cg": True, "noise": None}}\'']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-201-5ec8445e2f22> in <module>
#      20                     'precond_size': 10,
#      21                     'use_cg': True,
# ---> 22                     'noise': None
#      23                 }
#      24             },
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/runner.py in execute(*args, **kwargs)
#     197         func = notebook_run
#     198
# --> 199     return func(*args, **kwargs)
#     200
#     201
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/runner.py in notebook_run_server(*args, **kwargs)
#     163     ssh_cmd = hpc_wrap(cmd)
#     164     print(ssh_cmd)
# --> 165     subprocess.call(ssh_cmd)
#     166
#     167
#
# ~/anaconda3/envs/lions/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     287     with Popen(*popenargs, **kwargs) as p:
#     288         try:
# --> 289             return p.wait(timeout=timeout)
#     290         except:
#     291             p.kill()
#
# ~/anaconda3/envs/lions/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1475                         if self.returncode is not None:
#    1476                             break  # Another thread waited.
# -> 1477                         (pid, sts) = self._try_wait(0)
#    1478                         # Check the pid and loop as waitpid has been known to
#    1479                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/envs/lions/lib/python3.6/subprocess.py in _try_wait(self, wait_flags)
#    1422             """All callers to this function MUST hold self._waitpid_lock."""
#    1423             try:
# -> 1424                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1425             except ChildProcessError:
#    1426                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ### View

# %%
df = get_df()
exps_rows_df = df[df["tag"] == "uci"].copy()
exps_rows_df
# Out:
# Empty DataFrame
# Columns: [N, acq, bo, config, exp, f, id, model, model2, model_hash, name, result.WARNING, result.hyperparameters, result.max_err, result.rmse, result.time:pred, result.time:training, tag]
# Index: []

# %% [markdown]
# ## Scaling M (Natural Sound)

# %% [markdown]
# ### Create

# %%
Ms = [500, 1000, 2000, 3000, 5000, 10000]

for M in Ms:
    run = execute(config_updates={
        'tag': 'natural_sound',
        'obj_func': {
            'name': 'NaturalSound',
            'kwargs': {},
        },
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 100,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'n_grid': M},
                'max_cg_iter': 1500,
                'precond_size': 10,
                'use_cg': True,
                'noise': None
            }
        }
    })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 500}, "max_cg_iter": 1500, "precond_size": 10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 1000}, "max_cg_iter": 1500, "precond_size": 10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 2000}, "max_cg_iter": 1500, "precond_size": 10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 3000}, "max_cg_iter": 1500, "precond_size": 10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 5000}, "max_cg_iter": 1500, "precond_size": 10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 10000}, "max_cg_iter": 1500, "precond_size": 10, "use_cg": True, "noise": None}}\'']

# %%
Ms = [100, 500, 1000, 2000, 3000, 5000]

for M in Ms:
    for optimize_spectral_points in [True, False]:
        run = execute(config_updates={
            'tag': 'natural_sound',
            'obj_func': {
                'name': 'NaturalSound',
                'kwargs': {},
            },
            'model': {
                'name': 'SSGP',
                'kwargs': {
                    'learning_rate': 0.1,
                    'feature_extractor_constructor': {
                        'name': 'RFFEmbedding',
                        'kwargs': {
                            'M': M,
                            'optimize_spectral_points': optimize_spectral_points
                        }
                    },
                    'n_iter': 100,
                    'max_cg_iter': 1500,
                    'precond_size': 10,
                    'use_double_precision': True,
                    'noise_lower_bound': 1e-10,
                    'use_cg': True,
                    'noise': None
                }
            }
        })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 100, "optimize_spectral_points": True}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 100, "optimize_spectral_points": False}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 500, "optimize_spectral_points": True}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 500, "optimize_spectral_points": False}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 1000, "optimize_spectral_points": True}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 1000, "optimize_spectral_points": False}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 2000, "optimize_spectral_points": True}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 2000, "optimize_spectral_points": False}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 3000, "optimize_spectral_points": True}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 3000, "optimize_spectral_points": False}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 5000, "optimize_spectral_points": True}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SSGP", "kwargs": {"learning_rate": 0.1, "feature_extractor_constructor": {"name": "RFFEmbedding", "kwargs": {"M": 5000, "optimize_spectral_points": False}}, "n_iter": 100, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']

# %%
# SGPR for subset 10000
run = execute(config_updates={
    'tag': 'natural_sound',
    'obj_func': {
        'name': 'NaturalSound',
        'kwargs': {'subset_size': 10000},
    },
    'model': {
        'name': 'SGPR',
        'kwargs': {
            'learning_rate': 0.1,
            'n_iter': 100,
            'nn_kwargs': {'layers': None},
            'gp_kwargs': {'inducing_points': 5000},
            'max_cg_iter': 1500,
            'precond_size': 10,
            'use_double_precision': True,
            'noise_lower_bound': 1e-10,
            'use_cg': True,
            'noise': None
        }
    }
})

Ms = [100, 500, 1000, 2000, 3000, 5000]

for M in Ms:
    run = execute(config_updates={
        'tag': 'natural_sound',
        'obj_func': {
            'name': 'NaturalSound',
            'kwargs': {},
        },
        'model': {
            'name': 'SGPR',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 100,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'inducing_points': M},
                'max_cg_iter': 1500,
                'precond_size': 10,
                'use_double_precision': True,
                'noise_lower_bound': 1e-10,
                'use_cg': True,
                'noise': None
            }
        }
    })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 10000}}\' \'model={"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 5000}, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 100}, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 500}, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 1000}, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 2000}, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 3000}, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="natural_sound"\' \'obj_func={"name": "NaturalSound", "kwargs": {}}\' \'model={"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 5000}, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']

# %% [markdown]
# ### View

# %%
df = get_df()
exps_rows_df = df[df["tag"] == "natural_sound"].copy()
# Filter out n_iter=0
exps_rows_df = exps_rows_df[exps_rows_df.apply(lambda r: r.config.model.kwargs.get('n_iter', 0) > 1, axis=1)]
exps_rows_df
# Out:
#                                            N   acq     bo  \
# exp_hash
# 05d5d9217d716da14a1aba7cd8c8359da1d36165 NaN  None  False
# 0d75327c05d4d312cfc678571d27f16876f3258b NaN  None  False
# 1458e40ededa8083776eab6ebb7525c117d70837 NaN  None  False
# 227a86bacab0675c4030dc3eaa0f72eef294a1ab NaN  None  False
# 2c352b694bf9e846bcb7c3c3ee89be7c6ced1a64 NaN  None  False
# 3452f7a5b94bdf4b0b9ca92ab1a87f16b8a279ba NaN  None  False
# 38ecb75c93ecc93645f109831ac105f3283dee37 NaN  None  False
# 4085900fbc09a18d95ed8cba4568049b076f4961 NaN  None  False
# 556656d43e8fbf8a7b70ffb9636be95ac2ff867b NaN  None  False
# 5ba203085f9290647be1032e0fae3789bbe4d1a5 NaN  None  False
# 6f81c0dd0a310a3dee2d60b7e91fa746ad2a699a NaN  None  False
# 73cfa222062de328e9ac818960bf997ed603b65e NaN  None  False
# 7af23109eccd129bb858af82be68bfdf6fd89c2b NaN  None  False
# 87547c2fa3fe63ecb9927ced756aae7a3914716d NaN  None  False
# 8f12ef92750cc2b70dc6d1d3f5d9d1bdbe8fd91b NaN  None  False
# 99806a8fee2e3bbcb9f3591b1edbb352a226ef1f NaN  None  False
# a224a72f6cbd217972c47242ae3da96b60f56855 NaN  None  False
# a2a4bb16c48d4c63abf490472a8d67f87e167dfa NaN  None  False
# a62fbc296e0a87bcc121b089fbfcf3b7446840f9 NaN  None  False
# b5887f24e402e0200b8afc33cb17a89d72ebd79b NaN  None  False
# b78742e52b815cea2f039ddd33db8da5b4b50299 NaN  None  False
# bb2dcfc6108a5dbf7407e7bc96f5f5790a2be620 NaN  None  False
# bddaba325de844a218aa5ce067b76917ea35abfe NaN  None  False
# c42a84c25b990a54a393a4ce8423d54b9159ca2f NaN  None  False
# c8ae03f102bad4470a9a58df97f32953f6e5637b NaN  None  False
# c9fbf4dae7067d474f175134d6b2c9a046a79201 NaN  None  False
# dde54014ceb25c044dbaf193f3dad2a93dea716f NaN  None  False
# df0b409ad0b83d3793809376743cb8270faed087 NaN  None  False
# e585ac9a5203342042537ed5b97253b4bb3f3c9f NaN  None  False
# e696f3c525a2e674c557042a67db8ea9b4d6571d NaN  None  False
# e6fa58f1c88fb8fd36df5b6001cfae63b56a1919 NaN  None  False
# fc3db38d92fa7bfdfd29da3d3c2bec3d1506aae2 NaN  None  False
# fe074fff07c298ce60bea88aad85e213076179aa NaN  None  False
#
#                                                                                      config  \
# exp_hash
# 05d5d9217d716da14a1aba7cd8c8359da1d36165  {'exp_hash': '05d5d9217d716da14a1aba7cd8c8359d...
# 0d75327c05d4d312cfc678571d27f16876f3258b  {'exp_hash': '0d75327c05d4d312cfc678571d27f168...
# 1458e40ededa8083776eab6ebb7525c117d70837  {'exp_hash': '1458e40ededa8083776eab6ebb7525c1...
# 227a86bacab0675c4030dc3eaa0f72eef294a1ab  {'exp_hash': '227a86bacab0675c4030dc3eaa0f72ee...
# 2c352b694bf9e846bcb7c3c3ee89be7c6ced1a64  {'exp_hash': '2c352b694bf9e846bcb7c3c3ee89be7c...
# 3452f7a5b94bdf4b0b9ca92ab1a87f16b8a279ba  {'exp_hash': '3452f7a5b94bdf4b0b9ca92ab1a87f16...
# 38ecb75c93ecc93645f109831ac105f3283dee37  {'exp_hash': '38ecb75c93ecc93645f109831ac105f3...
# 4085900fbc09a18d95ed8cba4568049b076f4961  {'exp_hash': '4085900fbc09a18d95ed8cba4568049b...
# 556656d43e8fbf8a7b70ffb9636be95ac2ff867
# 556656d43e8fbf8a7b70ffb9636be95ac2ff867b  Experiment(id=1284, name=lions)
# 5ba203085f9290647be1032e0fae3789bbe4d1a5  Experiment(id=1278, name=lions)
# 6f81c0dd0a310a3dee2d60b7e91fa746ad2a699a  Experiment(id=1013, name=lions)
# 73cfa222062de328e9ac818960bf997ed603b65e  Experiment(id=1279, name=lions)
# 7af23109eccd129bb858af82be68bfdf6fd89c2b  Experiment(id=1285, name=lions)
# 87547c2fa3fe63ecb9927ced756aae7a3914716d  Experiment(id=1290, name=lions)
# 8f12ef92750cc2b70dc6d1d3f5d9d1bdbe8fd91b  Experiment(id=1275, name=lions)
# 99806a8fee2e3bbcb9f3591b1edbb352a226ef1f  Experiment(id=1286, name=lions)
# a224a72f6cbd217972c47242ae3da96b60f56855  Experiment(id=1276, name=lions)
# a2a4bb16c48d4c63abf490472a8d67f87e167dfa  Experiment(id=1451, name=lions)
# a62fbc296e0a87bcc121b089fbfcf3b7446840f9  Experiment(id=1435, name=lions)
# b5887f24e402e0200b8afc33cb17a89d72ebd79b  Experiment(id=1016, name=lions)
# b78742e52b815cea2f039ddd33db8da5b4b50299  Experiment(id=1282, name=lions)
# bb2dcfc6108a5dbf7407e7bc96f5f5790a2be620  Experiment(id=1283, name=lions)
# bddaba325de844a218aa5ce067b76917ea35abfe  Experiment(id=1450, name=lions)
# c42a84c25b990a54a393a4ce8423d54b9159ca2f  Experiment(id=1288, name=lions)
# c8ae03f102bad4470a9a58df97f32953f6e5637b  Experiment(id=1014, name=lions)
# c9fbf4dae7067d474f175134d6b2c9a046a79201  Experiment(id=1438, name=lions)
# dde54014ceb25c044dbaf193f3dad2a93dea716f  Experiment(id=1430, name=lions)
# df0b409ad0b83d3793809376743cb8270faed087  Experiment(id=1011, name=lions)
# e585ac9a5203342042537ed5b97253b4bb3f3c9f  Experiment(id=1448, name=lions)
# e696f3c525a2e674c557042a67db8ea9b4d6571d  Experiment(id=1012, name=lions)
# e6fa58f1c88fb8fd36df5b6001cfae63b56a1919  Experiment(id=1015, name=lions)
# fc3db38d92fa7bfdfd29da3d3c2bec3d1506aae2  Experiment(id=1429, name=lions)
# fe074fff07c298ce60bea88aad85e213076179aa  Experiment(id=1281, name=lions)
#
#                                                      f    id       model  \
# exp_hash
# 05d5d9217d716da14a1aba7cd8c8359da1d36165  NaturalSound  1433        SSGP
# 0d75327c05d4d312cfc678571d27f16876f3258b  NaturalSound  1452        SGPR
# 1458e40ededa8083776eab6ebb7525c117d70837  NaturalSound  1434        SSGP
# 227a86bacab0675c4030dc3eaa0f72eef294a1ab  NaturalSound  1277        SSGP
# 2c352b694bf9e846bcb7c3c3ee89be7c6ced1a64  NaturalSound  1431        SSGP
# 3452f7a5b94bdf4b0b9ca92ab1a87f16b8a279ba  NaturalSound  1280        SSGP
# 38ecb75c93ecc93645f109831ac105f3283dee37  NaturalSound  1287        SGPR
# 4085900fbc09a18d95ed8cba4568049b076f4961  NaturalSound  1432        SSGP
# 556656d43e8fbf8a7b70ffb9636be95ac2ff867b  NaturalSound  1284        SSGP
# 5ba203085f9290647be1032e0fae3789bbe4d1a5  NaturalSound  1278        SSGP
# 6f81c0dd0a310a3dee2d60b7e91fa746ad2a699a  NaturalSound  1013  DKLGPModel
# 73cfa222062de328e9ac818960bf997ed603b65e  NaturalSound  1279        SSGP
# 7af23109eccd129bb858af82be68bfdf6fd89c2b  NaturalSound  1285        SSGP
# 87547c2fa3fe63ecb9927ced756aae7a3914716d  NaturalSound  1290        SGPR
# 8f12ef92750cc2b70dc6d1d3f5d9d1bdbe8fd91b  NaturalSound  1275        SSGP
# 99806a8fee2e3bbcb9f3591b1edbb352a226ef1f  NaturalSound  1286        SSGP
# a224a72f6cbd217972c47242ae3da96b60f56855  NaturalSound  1276        SSGP
# a2a4bb16c48d4c63abf490472a8d67f87e167dfa  NaturalSound  1451        SGPR
# a62fbc296e0a87bcc121b089fbfcf3b7446840f9  NaturalSound  1435        SSGP
# b5887f24e402e0200b8afc33cb17a89d72ebd79b  NaturalSound  1016  DKLGPModel
# b78742e52b815cea2f039ddd33db8da5b4b50299  NaturalSound  1282        SSGP
# bb2dcfc6108a5dbf7407e7bc96f5f5790a2be
# c8ae03f102bad4470a9a58df97f32953f6e5637b                516.38  natural_sound
# c9fbf4dae7067d474f175134d6b2c9a046a79201               2935.44  natural_sound
# dde54014ceb25c044dbaf193f3dad2a93dea716f                903.25  natural_sound
# df0b409ad0b83d3793809376743cb8270faed087                757.55  natural_sound
# e585ac9a5203342042537ed5b97253b4bb3f3c9f                395.89  natural_sound
# e696f3c525a2e674c557042a67db8ea9b4d6571d                578.22  natural_sound
# e6fa58f1c88fb8fd36df5b6001cfae63b56a1919                629.82  natural_sound
# fc3db38d92fa7bfdfd29da3d3c2bec3d1506aae2                318.34  natural_sound
# fe074fff07c298ce60bea88aad85e213076179aa                991.94  natural_sound

# %%
def get_M(r):
    SS_M = r.config.model.kwargs.feature_extractor_constructor.kwargs.get('M', None)
    if SS_M is not None:
        return SS_M
    SGPR_M = r.config.model.kwargs.gp_kwargs.get('inducing_points', None)
    if SGPR_M is not None:
        return SGPR_M
    return r.config.model.kwargs.gp_kwargs.get('n_grid', None)

temp_df = aggregate_results(exps_rows_df)
temp_df['M'] = temp_df.apply(get_M, axis=1)
temp_df['double'] = temp_df.apply(lambda r: r.config.model.kwargs.get('use_double_precision', False), axis=1)
temp_df['fixed'] = temp_df.apply(lambda r: not r.config.model.kwargs.feature_extractor_constructor.kwargs.get('optimize_spectral_points', False), axis=1)
view_df(temp_df, indexes=['double', 'fixed', 'model', 'M'], cols=['result.rmse', 'result.max_err', 'result.time:training']).sort_index()
# Out:
#                                             result.rmse  result.max_err  \
# double fixed model      M     f
# False  False SSGP       100   NaturalSound     0.042777        0.169307
#                         500   NaturalSound     0.043162        0.166209
#                         1000  NaturalSound     0.044364        0.175022
#                         2000  NaturalSound     0.043349        0.170717
#                         3000  NaturalSound     0.043918        0.170044
#                         5000  NaturalSound     0.043247        0.170096
#        True  DKLGPModel 500   NaturalSound     0.045478        0.181186
#                         1000  NaturalSound     0.047155        0.185082
#                         2000  NaturalSound     0.040725        0.151638
#                         3000  NaturalSound     0.039473        0.191035
#                         5000  NaturalSound     0.020892        0.116237
#                         10000 NaturalSound     0.023410        0.153566
#              SGPR       100   NaturalSound     0.042894        0.169101
#                         500   NaturalSound     0.042894        0.169101
#                         1000  NaturalSound     0.042894        0.169101
#              SSGP       100   NaturalSound     0.044027        0.167798
#                         500   NaturalSound     0.043167        0.173566
#                         1000  NaturalSound     0.043549        0.167244
#                         2000  NaturalSound     0.043677        0.158474
#                         3000  NaturalSound     0.044368        0.152758
#                         5000  NaturalSound     0.045350        0.154654
# True   False SSGP       100   NaturalSound     0.042996        0.169943
#                         500   NaturalSound     0.042884        0.166184
#                         1000  NaturalSound     0.043235        0.167595
#                         2000  NaturalSound     0.042715        0.167450
#        True  SGPR       100   NaturalSound     0.042894        0.169101
#                         500   NaturalSound     0.042894        0.169101
#                         1000  NaturalSound     0.042894        0.169101
#                         2000  NaturalSound     0.042894        0.169101
#              SSGP       100   NaturalSound     0.043134        0.169193
#                         500   NaturalSound     0.043216        0.170803
#                         1000  NaturalSound     0.043030        0.161598
#                         2000  NaturalSound     0.043815        0.173515
#
#                                             result.time:training
# double fixed model      M     f
# False  False SSGP       100   NaturalSound                237.66
#                         500   NaturalSound                613.30
#                         1000  NaturalSound                936.45
#                         2000  NaturalSound               1797.20
#                         3000  NaturalSound               2529.07
#                         5000  NaturalSound               4226.55
#        True  DKLGPModel 500   NaturalSound                642.81
#                         1000  NaturalSound                516.38
#                         2000  NaturalSound                578.22
#                         3000  NaturalSound                567.00
#                         5000  NaturalSound                629.82
#                         10000 NaturalSound                757.55
#              SGPR       100   NaturalSound                264.25
#                         500   NaturalSound                724.31
#                         1000  NaturalSound               1630.45
#              SSGP       100   NaturalSound                230.48
#                         500   NaturalSound                616.42
#                         1000  NaturalSound                991.94
#                         2000  NaturalSound               1805.63
#                         3000  NaturalSound               2540.97
#                         5000  NaturalSound               4114.76
# True   False SSGP       100   NaturalSound                318.34
#                         500   NaturalSound                903.25
#                         1000  NaturalSound               1563.57
#                         2000  NaturalSound               2805.90
#        True  SGPR       100   NaturalSound                395.89
#                         500   NaturalSound               1326.90
#                         1000  NaturalSound               2668.57
#                         2000  NaturalSound               6612.28
#              SSGP       100   NaturalSound                374.57
#                         500   NaturalSound                998.44
#                         1000  NaturalSound               1656.07
#                         2000  NaturalSound               2935.44

# %%
# add result.rmse.std row.
# make new row
mean = 0.0444123123
std = 0.012
f"{mean:.3f} ± {std:.4f}"

# SSGP
# SSGP-fixed
# Out:
# '0.044 ± 0.0120'

# %%
select_experiment_with_rmse(temp_df, 0.042894)
# Out:
# {'exp_hash': '38ecb75c93ecc93645f109831ac105f3283dee37',
#  'gp_use_derivatives': False,
#  'model': {'kwargs': {'gp_kwargs': {'inducing_points': 100},
#                       'learning_rate': 0.1,
#                       'max_cg_iter': 1500,
#                       'n_iter': 100,
#                       'nn_kwargs': {'layers': None},
#                       'noise': None,
#                       'precond_size': 10,
#                       'use_cg': True},
#            'name': 'SGPR'},
#  'model_compare': False,
#  'model_hash': 'cd1c0d687a6df955b18dd38e8c6b1aa589e4528c',
#  'obj_func': {'kwargs': {}, 'name': 'NaturalSound'},
#  'seed': 898323245,
#  'tag': 'natural_sound',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# Experiment(id=1287, name=lions)

# %% [markdown]
# ### Figures

# %%
# Add mean and std
temp_df2 = exps_rows_df.copy()
temp_df2['M'] = temp_df2.apply(get_M, axis=1)
temp_df2 = aggregate_results(temp_df2, describe=True)

temp_df['result.rmse.mean'] = temp_df2[('result.rmse', 'mean')]
temp_df['result.rmse.std'] = temp_df2[('result.rmse', 'std')]

name_mapping = {
    'DKLGPModel': 'KISS-GP',
    'SGPR': 'SGPR',
    'SSGP': 'SSGP'
}

# %%
f = NaturalSound()
fig, ax = plt.subplots()
ax.plot(f.X_train, f.Y_train)
ax.set_xlabel('Time (s)')
ax.set_ylabel('Intensity')
savefig(fig, 'scalable/scalability-varying-M-dataset.pdf')

# %%
latexify(columns=2)

full_df = temp_df

markers = cycle_markers()
lines = cycle_lines()


fig, ax = plt.subplots()
for idx, model_df in full_df.groupby(['model']):
    model_df = model_df.sort_values('M')
    mean = model_df['result.rmse.mean']
    err = 2 * model_df['result.rmse.std']
    ax.errorbar(model_df['M'], mean, yerr=err, label=name_mapping[idx], marker=next(markers), linestyle=next(lines))
    ax.set_xlabel('M')
    ax.set_ylabel('RMSE')

ax.legend()

plt.tight_layout()
savefig(fig, 'scalable/scalability-varying-M.pdf')

# %%
latexify(columns=2)

full_df = temp_df

markers = cycle_markers()
lines = cycle_lines()

fig, ax = plt.subplots()
for idx, model_df in full_df.groupby(['model']):
    model_df = model_df.sort_values('M')
    time = model_df['result.time:training'] + model_df['result.time:pred']
    mean = model_df['result.rmse.mean']
    err = 2 * model_df['result.rmse.std']

    ax.errorbar(time, mean, yerr=err, label=name_mapping[idx], marker=next(markers), linestyle=next(lines))
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('RMSE')

ax.legend()

plt.tight_layout()
savefig(fig, 'scalable/scalability-varying-M-time.pdf')

# %%
latexify(columns=2)

full_df = temp_df

markers = cycle_markers()
lines = cycle_lines()

fig, ax = plt.subplots()
for idx, model_df in full_df.groupby(['model']):
    model_df = model_df.sort_values('M')
    time = model_df['result.time:training'] + model_df['result.time:pred']
    mean = model_df['result.rmse.mean']
    err = 2 * model_df['result.rmse.std']

    ax.errorbar(model_df['M'], time, yerr=err, label=name_mapping[idx], marker=next(markers), linestyle=next(lines))
    ax.set_xlabel('M')
    ax.set_ylabel('Time (s)')

ax.legend()

plt.tight_layout()
savefig(fig, 'scalable/scalability-varying-M-time-vs-M.pdf')

# %% [markdown]
# ## Scaling N (Natural Sound) [DONE]

# %% [markdown]
# ### Create

# %%
Ms = [10000, 15000]
Ns = [1000, 5000, 10000, 30000, 59309]

for M in Ms:
    for N in Ns:
        run = execute(config_updates={
            'tag': 'natural_sound-N',
            'obj_func': {
                'name': 'NaturalSound',
                'kwargs': {'subset_size': N},
            },
            'model': {
                'name': 'DKLGPModel',
                'kwargs': {
                    'learning_rate': 0.1,
                    'n_iter': 200,
                    'nn_kwargs': {'layers': None},
                    'gp_kwargs': {'n_grid': M},
                    'max_cg_iter': 3000,
                    'precond_size': 10,
                    'use_double_precision': True,
                    'noise_lower_bound': 1e-10,
                    'use_cg': True,
                    'noise': None
                }
            }
        })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 1000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 10000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 5000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 10000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 10000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 10000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 30000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 10000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 59309}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 10000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 1000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 15000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 5000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 15000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 10000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 15000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 30000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 15000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 59309}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 200, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 15000}, "max_cg_iter": 3000, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "use_cg": True, "noise": None}}\'']

# %%
# ExactGP
Ns = [1000, 5000, 10000, 30000, 59309]

for N in Ns:
    run = execute(config_updates={
        'tag': 'natural_sound-N',
        'obj_func': {
            'name': 'NaturalSound',
            'kwargs': {'subset_size': N},
        },
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 100,
                'nn_kwargs': {'layers': None},
                'use_cg': False,
                'use_double_precision': True,
                'noise_lower_bound': 1e-10,
                'noise': None
            }
        }
    })

    run = execute(config_updates={
        'tag': 'natural_sound-N',
        'obj_func': {
            'name': 'NaturalSound',
            'kwargs': {'subset_size': N},
        },
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 100,
                'nn_kwargs': {'layers': None},
                'use_cg': False,
                'noise': None
            }
        }
    })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 1000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 1000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 5000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 5000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 10000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 10000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 30000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 30000}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 59309}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--natural_sound-N"\' \'obj_func={"name": "NaturalSound", "kwargs": {"subset_size": 59309}}\' \'model={"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "use_cg": False, "noise": None}}\'']

# %% [markdown]
# ### View

# %%
df = get_df()
exps_rows_df = df[df["tag"] == "final--natural_sound-N"].copy()
exps_rows_df
# Out:
#                                                 N   acq     bo  \
# exp_hash
# 0ccea4c567dc87ad43962af7b6d1e2847284b2d
# c7d6000270b5bb0f31fbfbd6db6f483a4e0f08c0              23300.17
# cc5b679a1f2acf5e746c860824e802cf4b6610a5               2046.26
# d18b62be71c0323fc8d367b0f8c47e7188baa73b               1464.30
# d4925062a5e19dd9ad0f3e2ae36984e97644fe2a                 77.66
# d9eed240d46e41a7656583ddfd00a55990ec1afa               1325.22
# ddb3f0cf4bd8f827b6a2be59331ea82c220f2e23               1011.85
# fa595dec378f4fbf1093fd4125b3b4529321e621               1850.30
#
#                                                              tag
# exp_hash
# 0ccea4c567dc87ad43962af7b6d1e2847284b2d4  final--natural_sound-N
# 3eecb7e0824b9d18a7d91005e94e3f93bab0b423  final--natural_sound-N
# 43b8d02b0668484b5149ccaa203a90dcc5fbdd43  final--natural_sound-N
# 5485bd2f3e2114389a54704bce70445723b29743  final--natural_sound-N
# 9f1e76b7e9c60c242b8a7d2997f2011153ebb119  final--natural_sound-N
# 9f79bcefd6374acf1bf42f93671272c747816731  final--natural_sound-N
# 9fc2028de405ba5aec980a52f87f4aaa7236854c  final--natural_sound-N
# c7d6000270b5bb0f31fbfbd6db6f483a4e0f08c0  final--natural_sound-N
# c7d6000270b5bb0f31fbfbd6db6f483a4e0f08c0  final--natural_sound-N
# c7d6000270b5bb0f31fbfbd6db6f483a4e0f08c0  final--natural_sound-N
# c7d6000270b5bb0f31fbfbd6db6f483a4e0f08c0  final--natural_sound-N
# c7d6000270b5bb0f31fbfbd6db6f483a4e0f08c0  final--natural_sound-N
# cc5b679a1f2acf5e746c860824e802cf4b6610a5  final--natural_sound-N
# d18b62be71c0323fc8d367b0f8c47e7188baa73b  final--natural_sound-N
# d4925062a5e19dd9ad0f3e2ae36984e97644fe2a  final--natural_sound-N
# d9eed240d46e41a7656583ddfd00a55990ec1afa  final--natural_sound-N
# ddb3f0cf4bd8f827b6a2be59331ea82c220f2e23  final--natural_sound-N
# fa595dec378f4fbf1093fd4125b3b4529321e621  final--natural_sound-N

# %%
def get_M(r):
    SS_M = r.config.model.kwargs.feature_extractor_constructor.kwargs.get('M', None)
    if SS_M is not None:
        return SS_M
    SGPR_M = r.config.model.kwargs.gp_kwargs.get('inducing_points', None)
    if SGPR_M is not None:
        return SGPR_M
    return r.config.model.kwargs.gp_kwargs.get('n_grid', None)

temp_df = aggregate_results(exps_rows_df)
temp_df['M'] = temp_df.apply(get_M, axis=1)
temp_df['double'] = temp_df.apply(lambda r: r.config.model.kwargs.get('use_double_precision', False), axis=1)
view_df(temp_df, indexes=['double', 'model', 'M', 'N'], cols=['result.rmse', 'result.max_err', 'result.time:training']).sort_index()
# Out:
#                                                 result.rmse  result.max_err  \
# double model      M       N       f
# False  DKLGPModel NaN     1000.0  NaturalSound     0.040630        0.165802
# True   DKLGPModel 10000.0 1000.0  NaturalSound     0.042743        0.169101
#                           5000.0  NaturalSound     0.041046        0.173296
#                           10000.0 NaturalSound     0.032835        0.152665
#                           30000.0 NaturalSound     0.025855        0.154486
#                           59309.0 NaturalSound     0.021476        0.129095
#                   15000.0 1000.0  NaturalSound     0.042885        0.169101
#                           5000.0  NaturalSound     0.041783        0.171764
#                           10000.0 NaturalSound     0.030046        0.190531
#                           30000.0 NaturalSound     0.010071        0.055025
#                           59309.0 NaturalSound     0.008850        0.070356
#                   NaN     1000.0  NaturalSound     0.039687        0.169101
#                           5000.0  NaturalSound     0.030635        0.144524
#                           10000.0 NaturalSound     0.025323        0.129459
#
#                                                 result.time:training
# double model      M       N       f
# False  DKLGPModel NaN     1000.0  NaturalSound                 65.78
# True   DKLGPModel 10000.0 1000.0  NaturalSound                836.76
#                           5000.0  NaturalSound               1011.85
#                           10000.0 NaturalSound               1150.31
#                           30000.0 NaturalSound               1464.30
#                           59309.0 NaturalSound               1850.30
#                   15000.0 1000.0  NaturalSound               1090.08
#                           5000.0  NaturalSound               1235.28
#                           10000.0 NaturalSound               1325.22
#                           30000.0 NaturalSound               1583.48
#                           59309.0 NaturalSound               2046.26
#                   NaN     1000.0  NaturalSound                 77.66
#                           5000.0  NaturalSound               3390.84
#                           10000.0 NaturalSound              23362.37

# %%
select_experiment_with_rmse(temp_df, 0.027149).result
# Out:
# {'exp_hash': '23f0aa4a9ed4ff8e801b779b9102bf5f3928e246',
#  'gp_use_derivatives': False,
#  'model': {'kwargs': {'gp_kwargs': {'n_grid': 10000},
#                       'learning_rate': 0.1,
#                       'max_cg_iter': 3000,
#                       'n_iter': 200,
#                       'nn_kwargs': {'layers': None},
#                       'noise': None,
#                       'precond_size': 10,
#                       'use_cg': True},
#            'name': 'DKLGPModel'},
#  'model_compare': False,
#  'model_hash': 'd876e01b7dc8a8c5333bea777382608adba3b23b',
#  'obj_func': {'kwargs': {'subset_size': 1000}, 'name': 'NaturalSound'},
#  'seed': 35874499,
#  'tag': 'natural_sound-N',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# {'hyperparameters': {'lengthscale': {'py/object': 'numpy.ndarray',
#    'values': [[0.6931471824645996]],
#    'dtype': 'float32'},
#   'noise': 0.0004359336744528264,
#   'outputscale': {'py/object': 'numpy.ndarray',
#    'values': 0.001457810285501182,
#    'dtype': 'float32'}},
#  'max_err': 0.16911688124218074,
#  'rmse': 0.042824888375182654,
#  'time:pred': 6.730000000000018,
#  'time:training': 712.96}

# %%
select_experiment_with_rmse(temp_df, 0.022717).result
# Out:
# {'exp_hash': '3d6ce01e9396c3f8d13aa0f55f9d5a703527d5bb',
#  'gp_use_derivatives': False,
#  'model': {'kwargs': {'gp_kwargs': {'n_grid': 10000},
#                       'learning_rate': 0.1,
#                       'max_cg_iter': 3000,
#                       'n_iter': 200,
#                       'nn_kwargs': {'layers': None},
#                       'noise': None,
#                       'precond_size': 10,
#                       'use_cg': True},
#            'name': 'DKLGPModel'},
#  'model_compare': False,
#  'model_hash': 'd876e01b7dc8a8c5333bea777382608adba3b23b',
#  'obj_func': {'kwargs': {'subset_size': 59309}, 'name': 'NaturalSound'},
#  'seed': 885470509,
#  'tag': 'natural_sound-N',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# {'hyperparameters': {'lengthscale': {'py/object': 'numpy.ndarray',
#    'values': [[0.6931472420692444]],
#    'dtype': 'float32'},
#   'noise': 0.00011145226017106324,
#   'outputscale': {'py/object': 'numpy.ndarray',
#    'values': 0.0016022808849811554,
#    'dtype': 'float32'}},
#  'max_err': 0.14667870531501706,
#  'rmse': 0.022720625563595196,
#  'time:pred': 23.330000000000155,
#  'time:training': 1571.86}

# %% [markdown]
# ### Figures

# %%
# Add mean and std
temp_df2 = exps_rows_df.copy()
temp_df2['M'] = temp_df2.apply(get_M, axis=1)
temp_df2 = aggregate_results(temp_df2, describe=True)

temp_df['result.rmse.mean'] = temp_df2[('result.rmse', 'mean')]
temp_df['result.rmse.std'] = temp_df2[('result.rmse', 'std')]

# %%
latexify(columns=2)
markers = cycle_markers()
lines = cycle_lines()

full_df = temp_df

fig, ax = plt.subplots()

name_mapping = {
    'DKLGPModel': 'KISS-GP',
    'SGPR': 'SGPR',
    'SSGP': 'SSGP'
}

def get_name(name, M):
    if M == -1:
        return 'ExactGP'
    else:
        return f'KISS-GP M={M}'

full_df['M'] = full_df['M'].fillna(-1).astype(int)
for idx, model_df in full_df.groupby(['model', 'M']):
    name = get_name(*idx)
    model_df = model_df.sort_values('N')
    mean = model_df['result.rmse.mean']
    err = 2 * model_df['result.rmse.std']
    #ax.plot(model_df['N'], mean, label=idx, marker=next(markers))
    ax.errorbar(model_df['N'], mean, yerr=err, label=name, marker=next(markers), linestyle=next(lines))
    ax.set_xlabel('N')
    ax.set_ylabel('RMSE')

ax.legend()

plt.tight_layout()
savefig(fig, 'scalable/scalability-varying-N.pdf')

# %%
latexify(columns=2)
full_df = temp_df

markers = cycle_markers()

fig, ax = plt.subplots()
for idx, model_df in full_df.groupby(['model', 'M']):
    name = get_name(*idx)
    model_df = model_df.sort_values('N')
    time = model_df['result.time:training'] + model_df['result.time:pred']
    mean = model_df['result.rmse.mean']
    err = 2 * model_df['result.rmse.std']
    ax.errorbar(time, mean, yerr=err, label=name, marker=next(markers), linestyle=next(lines))
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('RMSE')

ax.legend()

plt.tight_layout()
savefig(fig, 'scalable/scalability-varying-N-time.pdf')

# %%
# H1: Observe the drop around 19200. When it perfectly aligns with the observations. Biased!

# Inducing points...

# %% [markdown]
# ## 2D smooth

# %% [markdown]
# ### Create

# %%
# Try double with added noise
Ns = [100]
Ms = [100]

kissmodels = lambda N, M: {
    'name': 'NormalizerModel',
    'kwargs': {
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 100,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'n_grid': M},
                'max_cg_iter': 3000,
                'precond_size': 10,
                'use_cg': True,
                'noise': None,
                'eval_cg_tolerance': 1e-5,
                'use_double_precision': True,
                'noise_lower_bound': 1e-10,
            }
        }
    }
}
    
# Run KISS-GP
for N in Ns:
    for M in Ms:
        run = execute(config_updates={
            'tag': 'scalable-smooth',
            'obj_func': {
                'name': 'Branin',
                'kwargs': {'noise': 5}
            },
            'model': kissmodels(N, M),
            'gp_samples': N ** 2,
            #'use_sample_grid': True,
        })
# Out:
# [autoreload of src.experiment.runner failed: Traceback (most recent call last):
#   File "/Users/tmpethick/anaconda3/envs/lions/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/tmpethick/anaconda3/envs/lions/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/tmpethick/anaconda3/envs/lions/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/Users/tmpethick/anaconda3/envs/lions/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/tmpethick/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/experiment/runner.py", line 11, in <module>
#     from src.models.core_models import MarginalLogLikelihoodMixin
# ImportError: cannot import name 'MarginalLogLikelihoodMixin'
# ]
# [autoreload of src.models failed: Traceback (most recent call last):
#   File "/Users/tmpethick/anaconda3/envs/lions/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/tmpethick/anaconda3/envs/lions/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 378, in superreload
#     module = reload(module)
#   File "/Users/tmpethick/anaconda3/envs/lions/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/Users/tmpethick/anaconda3/envs/lions/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/tmpethick/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/models/__init__.py", line 19, in <module>
#     from src.models.DKL.feature_models import LinearFromFeatureExtractor, SSGP, SGPR, DKLGPModel, DNGO
# ImportError: cannot import name 'DNGO'
# ]
# WARNING - lions - No observers have been added to this run
# INFO - lions - Running command 'main'
# INFO - lions - Started
# INFO - main - Model0: NormalizerModel training on 10000 of dim 2
# training on 10000 data points of dim 2
# INFO - dklgpmodel_training_callback - Iter 1/100 - Loss: 0.756
# Current hyperparameters: {'outputscale': array(0.69314718), 'lengthscale': array([[0.69314718, 0.69314718]]), 'noise': 0.6931471806599453}
# WARNING - lions - Aborted after 0:00:05!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-cf8dd7316396> in <module>
#      35             },
#      36             'model': kissmodels(N, M),
# ---> 37             'gp_samples': N ** 2,
#      38             #'use_sample_grid': True,
#      39         })
#
# <ipython-input-2-a2d6234bbe20> in execute(config_updates, *args, **kwargs)
#       8 def execute(*args, config_updates=None, **kwargs):
#       9     config_updates['tag'] = 'final--' + config_updates['tag']
# ---> 10     return execute_(*args, config_updates=config_updates, **kwargs)
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/runner.py in execute(*args, **kwargs)
#     197         func = notebook_run
#     198
# --> 199     return func(*args, **kwargs)
#     200
#     201
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/runner.py in notebook_run(*args, **kwargs)
#     184     ex = create_ex(interactive=True)
#     185     kwargs = dict(options = {'--force': True}, **kwargs)
# --> 186     return ex.run(*args, **kwargs)
#     187
#     188
#
# ~/anaconda3/envs/lions/lib/python3.6/site-packages/sacred/experiment.py in run(self, command_name, config_updates, named_configs, meta_info, options)
#     210         run = self._create_run(command_name, config_updates, named_configs,
#     211                                meta_info, options)
# --> 212         run()
#     213         return run
#     214
#
# ~/anaconda3/envs/lions/lib/python3.6/site-packages/sacred/run.py in __call__(self, *args)
#     231                 self._start_heartbeat()
#     232                 self._execute_pre_run_hooks()
# --> 233                 self.result = self.main_function(*args)
#     234                 self._execute_post_run_hooks()
#     235                 if self.result is not None:
#
# ~/anaconda3/envs/lions/lib/python3.6/site-packages/sacred/config/captured_function.py in captured_function(wrapped, instance, args, kwargs)
#      46     # =================== run actual function =================================
#      47     with ConfigError.track(wrapped):
# ---> 48         result = wrapped(*args, **kwargs)
#      49     # =========================================================================
#      50     if wrapped.logger is not None:
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/runner.py in main(_config, _run, _log)
#     100         # Run experiment
#     101         runner = Runner(context, _log, _run)
# --> 102         runner.run()
#     103
#     104         #Hack to have model available after run in interactive mode.
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/experiment/runner.py in run(self)
#      70
#      71         elif isinstance(f, BaseEnvironment):
# ---> 72             X_train, Y_train, Y_train_dir, X_test, Y_test, X_post_train, Y_post_train = self.get_data_f(f)
#      73             self.run_models(models, X_train, Y_train, Y_train_dir, X_test, Y_test, X_post_train, Y_post_train)
#      74
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/experiment/runner.py in run_models(self, models, X_train, Y_train, Y_train_dir, X_test, Y_test, X_post_train, Y_post_train)
#     118                 model.fit(f)
#     119             else:
# --> 120                 self.log_info('Model{}: {} training on {} of dim {}'.format(i, model, len(X_train), X_train.shape[-1]))
#     121                 model.init(X_train, Y_train, Y_dir=Y_train_dir)
#     122                 if X_post_train is not None:
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/models/normalizer.py in init(self, X, Y, Y_dir)
#      83
#      84             X, Y = self._normalize(X, Y)
# ---> 85             self.model.init(X, Y, Y_dir)
#      86
#      87         def add_observations(self, X_new, Y_new, Y_dir_new=None):
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/models/core_models.py in init(self, X, Y, Y_dir)
#      37         self.Y_dir = Y_dir
#      38
# ---> 39         self._fit(X, Y, Y_dir=self.Y_dir)
#      40
#      41     def add_observations(self, X_new, Y_new, Y_dir_new=None):
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/models/DKL/feature_models.py in _fit(self, X, Y, Y_dir)
#     262     def _fit(self, X, Y, Y_dir=None):
#     263         # catch warning, save and stop (runner should store this warning)
# --> 264         self._train(X, Y, fix_gp_params=False)
#     265
#     266     def make_double(self, tensor):
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/models/DKL/feature_models.py in _train(self, X, Y, fix_gp_params)
#     318             self.initialize_parameters(**self.initial_parameters)
#     319
# --> 320         self.optimize(self.X_torch, self.Y_torch, fix_gp_params=fix_gp_params)
#     321
#     322     def set_train_data(self, X, Y):
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/models/DKL/feature_models.py in optimize(self, X, Y, fix_gp_params)
#     388                 warnings.simplefilter("always")
#     389
# --> 390                 _train()
#     391
#     392                 self.store_CG_warning('training', w)
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/src/models/DKL/feature_models.py in _train()
#     369                 # Calc loss and backprop derivatives
#     370                 loss = -self.mll(output, Y)
# --> 371                 loss.backward()
#     372
#     373                 loss_ = loss.item()
#
# ~/anaconda3/envs/lions/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# ~/anaconda3/envs/lions/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
Ns = [100]
Ms = [100]

kissmodels = lambda N, M: {
    'name': 'NormalizerModel',
    'kwargs': {
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 100,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'n_grid': M},
                'max_cg_iter': 3000,
                'precond_size': 10,
                'use_cg': True,
                'noise': None,
                'eval_cg_tolerance': 1e-5,
            }
        }
    }
}
    
# Run KISS-GP
for N in Ns:
    for M in Ms:
        run = execute(config_updates={
            'tag': 'scalable-smooth',
            'obj_func': {
                'name': 'Branin',
            },
            'model': kissmodels(N, M),
            'gp_samples': N ** 2,
            #'use_sample_grid': True,
        })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 100}, "max_cg_iter": 3000, "precond_size": 10, "use_cg": True, "noise": None, "eval_cg_tolerance": 1e-05}}}}\' \'gp_samples=10000\'']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-198-f71ea2ff5f75> in <module>
#      31             },
#      32             'model': kissmodels(N, M),
# ---> 33             'gp_samples': N ** 2,
#      34             #'use_sample_grid': True,
#      35         })
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/runner.py in execute(*args, **kwargs)
#     197         func = notebook_run
#     198
# --> 199     return func(*args, **kwargs)
#     200
#     201
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/runner.py in notebook_run_server(*args, **kwargs)
#     163     ssh_cmd = hpc_wrap(cmd)
#     164     print(ssh_cmd)
# --> 165     subprocess.call(ssh_cmd)
#     166
#     167
#
# ~/anaconda3/envs/lions/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     287     with Popen(*popenargs, **kwargs) as p:
#     288         try:
# --> 289             return p.wait(timeout=timeout)
#     290         except:
#     291             p.kill()
#
# ~/anaconda3/envs/lions/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1475                         if self.returncode is not None:
#    1476                             break  # Another thread waited.
# -> 1477                         (pid, sts) = self._try_wait(0)
#    1478                         # Check the pid and loop as waitpid has been known to
#    1479                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/envs/lions/lib/python3.6/subprocess.py in _try_wait(self, wait_flags)
#    1422             """All callers to this function MUST hold self._waitpid_lock."""
#    1423             try:
# -> 1424                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1425             except ChildProcessError:
#    1426                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
Ns = [10, 32, 50, 100, 140]
Ms = [100, 140, 200]

kissmodels = lambda N, M: {
    'name': 'NormalizerModel',
    'kwargs': {
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 100,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'n_grid': M},
                'max_cg_iter': 3000,
                'precond_size': 10,
                'use_cg': True,
                'noise': None,
                'use_double_precision': True,
                'noise_lower_bound': 1e-10,
                'eval_cg_tolerance': 1e-5,
            }
        }
    }
}
    
# Run KISS-GP
for N in Ns:
    for M in Ms:
        run = execute(config_updates={
            'tag': 'scalable-smooth',
            'obj_func': {
                'name': 'Branin',
            },
            'model': kissmodels(N, M),
            'gp_samples': N ** 2,
            #'use_sample_grid': True,
        })

# %% [raw]
# # Gpy grid and no-grid
#
# Ns = [10, 32, 50, 100]
#
# gp = lambda N: {
#     'name': 'NormalizerModel',
#     'kwargs': {
#         'model': {
#             'name': 'GPModel',
#             'kwargs': dict(
#                 kernel=dict(
#                     name='GPyRBF',
#                     kwargs={'ARD': True},
#                 ),
#                 noise_prior=None,
#                 do_optimize=True,
#                 num_mcmc=0,
#             )
#         },
#     }
# }
#
# for N in Ns:
#     run = execute(config_updates={
#         'tag': 'scalable-smooth',
#         'obj_func': {
#             'name': 'Branin',
#         },
#         'model': gp(N),
#         'gp_samples': N,
#         'use_sample_grid': True,
#     })
#
# for N in Ns:
#     run = execute(config_updates={
#         'tag': 'scalable-smooth',
#         'obj_func': {
#             'name': 'Branin',
#         },
#         'model': gp(N),
#         'gp_samples': N ** 2,
#     })

# %%
# CG with GPyTorch

Ns = [10, 32, 50, 100]

gp = {
    'name': 'NormalizerModel',
    'kwargs': {
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 100,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'n_grid': None},
                'max_cg_iter': 3000,
                'precond_size': 10,
                'use_cg': True,
                'noise': None,
                'use_double_precision': True,
                'noise_lower_bound': 1e-10,
                'eval_cg_tolerance': 1e-5,
            }
        }
    }
}
    
for N in Ns:
    run = execute(config_updates={
        'tag': 'scalable-smooth',
        'obj_func': {
            'name': 'Branin',
        },
        'model': gp,
        'gp_samples': N ** 2,
    })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "max_cg_iter": 3000, "precond_size": 10, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10, "eval_cg_tolerance": 1e-05}}}}\' \'gp_samples=100\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "max_cg_iter": 3000, "precond_size": 10, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10, "eval_cg_tolerance": 1e-05}}}}\' \'gp_samples=1024\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "max_cg_iter": 3000, "precond_size": 10, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10, "eval_cg_tolerance": 1e-05}}}}\' \'gp_samples=2500\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "max_cg_iter": 3000, "precond_size": 10, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10, "eval_cg_tolerance": 1e-05}}}}\' \'gp_samples=10000\'']

# %%
# exactGP with GPyTorch

Ns = [10, 32, 50, 100]

gp = {
    'name': 'NormalizerModel',
    'kwargs': {
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 100,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'n_grid': None},
                'use_cg': False,
                'noise': None,
                'use_double_precision': True,
                'noise_lower_bound': 1e-10,
            }
        }
    }
}

for N in Ns:
    run = execute(config_updates={
        'tag': 'scalable-smooth',
        'obj_func': {
            'name': 'Branin',
        },
        'model': gp,
        'gp_samples': N ** 2,
    })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "use_cg": False, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10}}}}\' \'gp_samples=100\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "use_cg": False, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10}}}}\' \'gp_samples=1024\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "use_cg": False, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10}}}}\' \'gp_samples=2500\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 100, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "use_cg": False, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10}}}}\' \'gp_samples=10000\'']

# %%
# SGPR 

M = 1000
Ns = [10, 32, 50, 100]

gp = {
    'name': 'NormalizerModel',
    'kwargs': {
        'model': {
            'name': 'SGPR',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 10,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'inducing_points': M},
                'max_cg_iter': 3000,
                'precond_size': 10,
                'use_cg': True,
                'noise': None,
                'use_double_precision': True,
                'noise_lower_bound': 1e-10,
                'eval_cg_tolerance': 1e-5,
            }
        }
    }
}
    
for N in Ns:
    run = execute(config_updates={
        'tag': 'scalable-smooth',
        'obj_func': {
            'name': 'Branin',
        },
        'model': gp,
        'gp_samples': N ** 2,
    })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 10, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 1000}, "max_cg_iter": 3000, "precond_size": 10, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10, "eval_cg_tolerance": 1e-05}}}}\' \'gp_samples=100\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 10, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 1000}, "max_cg_iter": 3000, "precond_size": 10, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10, "eval_cg_tolerance": 1e-05}}}}\' \'gp_samples=1024\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 10, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 1000}, "max_cg_iter": 3000, "precond_size": 10, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10, "eval_cg_tolerance": 1e-05}}}}\' \'gp_samples=2500\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="scalable-smooth"\' \'obj_func={"name": "Branin"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "SGPR", "kwargs": {"learning_rate": 0.1, "n_iter": 10, "nn_kwargs": {"layers": None}, "gp_kwargs": {"inducing_points": 1000}, "max_cg_iter": 3000, "precond_size": 10, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-10, "eval_cg_tolerance": 1e-05}}}}\' \'gp_samples=10000\'']

# %% [markdown]
# ### View

# %%
df = get_df()
exps_rows_df = df[df["tag"] == "scalable-smooth"].copy()
exps_rows_df
# Out:
#                                                 N   acq     bo  \
# exp_hash
# 07b37aee9bfa261900cd66843c6322c2d30bbd16    100.0  None  False
# 0ad8e6b72880d1908b3880e67a04adb6705161ed    100.0  None  False
# 0b1bb135cb3a3d9d286e7c487ae73e790883f044  10000.0  None  False
# 0b7c69191847ef6b6edfd1e70da97c1d4bac474b    100.0  None  False
# 0d5c6b500626d7a4980dc5742f9232e8da270da4   1024.0  None  False
# 0e4aed49465fc30b517c65ff81afa947801512c6   2500.0  None  False
# 19e4bdbdf6669b737062f53bcb292c6d403a84fb  10000.0  None  False
# 1b582ecaf251fcbdca006946c92305163a227d4b    100.0  None  False
# 1b974c18747c738149c9d9d74327d8c7673ecb69  10000.0  None  False
# 1c2dac0621bcce6e8b92a5988e451cd405fb05a3  10000.0  None  False
# 24675773c0c7107192e9686d2990d134346b17b8    100.0  None  False
# 26dd54cbade11dbcff5cc7b88dcf5da12d08ee79   1024.0  None  False
# 278739c604338df2de93b500621b0977d81bc6e7   2500.0  None  False
# 29be3c654f449413c919670026e88b21bbfe1d44    100.0  None  False
# 371cf8d77ab7d2db6e98a0bbf2b79b76bdb3490d
# 773385daef7bc30af9cd6c532b1d34ba8a39ae86  Experiment(id=1336, name=lions)
# 8f987ce4f20499387e42fcccbfb0695999bc1221  Experiment(id=1385, name=lions)
# 9319e8a40f7423977d65aea1d58c89070f412570  Experiment(id=1308, name=lions)
# 961f61301c44057e106b2ddd96a8959e1f90b654  Experiment(id=1378, name=lions)
# 971f880db2017788381658b6e5f4d5116dc2c1b8  Experiment(id=1298, name=lions)
# 999f24501f74a8901780ba43edda5f65926d4d16  Experiment(id=1338, name=lions)
# 9fc7eddf843c67db91b7ec0c61185f0fbcf15ffc  Experiment(id=1344, name=lions)
# a08433e12a1b2110c576103227b1f9b33cb1e720  Experiment(id=1307, name=lions)
# ab7d75f55ec7840e458d40a431c41a63fe423835  Experiment(id=1310, name=lions)
# aeb6c4b2ca7aa972a121d5b0b99adf49f4c415a7  Experiment(id=1370, name=lions)
# aeddac54a75d071981c83679a8574d8b7f5f2d34  Experiment(id=1342, name=lions)
# af105b90ea04ae8e78d174881312073ece7820e0  Experiment(id=1339, name=lions)
# b63d0d547b49c59c1f3e94abb7d8311f136546f9  Experiment(id=1341, name=lions)
# ba2a84ccf4cf81f278e5ee1c63e5fd54a9204920  Experiment(id=1309, name=lions)
# bd03428bafe8a3afa8fd28c24e82f55bab889423  Experiment(id=1300, name=lions)
# c052205058ee2c7d7afdb322227d2730e8e06056  Experiment(id=1380, name=lions)
# c1e7cb2917bdcfe7baa32af37ffb3023badcc41c  Experiment(id=1382, name=lions)
# c642f0eaa382f1252000409683219a7d6870a608  Experiment(id=1381, name=lions)
# c85efaef5f3c67f5e6c63ef0fee47ca595102d48  Experiment(id=1365, name=lions)
# d843b232ad144b3a59eafa5688f0462b1f271deb  Experiment(id=1354, name=lions)
# d9fee56b88d0c9f96b46dcbb9a6c315a8b77aea3  Experiment(id=1317, name=lions)
# db1a75a9b6744424bce340b54f375acb9ea231fe  Experiment(id=1314, name=lions)
# dd65fb0a8981b95fd579311fb0997902dbc6768a  Experiment(id=1384, name=lions)
# eb5e37ec6a23900f3fecba05d84b946a736dac7e  Experiment(id=1335, name=lions)
# ec8a97568b7cbf6126fb23e166810648e4a0afd0  Experiment(id=1351, name=lions)
# ef2ad970e6b5af71306bce1b26a6ddd19a6b2f94  Experiment(id=1312, name=lions)
# f6fcc5f764c436b213612e093deda96a23d331c6  Experiment(id=1367, name=lions)
# f754177239020ab45a994b72545130ad707f243b  Experiment(id=1350, name=lions)
# fe7914956fd3a60181a937e4e1814dfd84879687  Experiment(id=1355, name=lions)
#
#                                                f    id          model model2  \
# exp_hash
# 07b37aee9bfa261900cd66843c6322c2d30bbd16  Branin  1315  N<DKLGPModel>   None
# 0ad8e6b72880d1908b3880e67a04adb6705161ed  Branin  1349  N<DKLGPModel>   None
# 0b1bb135cb3a3d9d286e7c487ae73e790883f044  Branin  1373  N<DKLGPModel>   None
# 0b7c69191847ef6b6edfd1e70da97c1d4bac474b  Branin  1337  N<DKLGPModel>   None
# 0d5c6b500626d7a4980dc5742f9232e8da270da4  Branin  1299  N<DKLGPModel>   None
# 0e4aed49465fc30b517c65ff81afa947801512c6  Branin  1302  N<DKLGPModel>   None
# 19e4bdbdf6669b737062f53bcb292c6d403a84fb  Branin  1306  N<DKLGPModel>   None
# 1b582ecaf251fcbdca006946c92305163a227d4b  Branin  1334  N<DKLGPModel>   None
# 1b974c18747c738149c9d9d74327d8c7673ecb69  Branin  1379  N<DKLGPModel>   None
# 1c2dac0621bcce6e8b92a5988e451cd405fb05a3  Branin  1427  N<DKLGPModel>   None
# 24675773c0c7107192e9686d2990d134346b17b8  Branin  1352  N<DKLGPModel>   None
# 26dd54cbade11dbcff5cc7b88dcf5da12d08ee79  Branin  1301  N<DKLGPModel>   None
# 278739c604338df2de93b500621b0977d81bc6e7  Branin  1368  N<DKLGPModel>   None
# 29be3c654f449413c919670026e88b21bbfe1d44  Branin  1364  N<DKLGPModel>   None
# 371cf8d77ab7d2db6e98a0bbf2b79b76bdb3490d  Branin  1353  N<DKLGPModel>   None
# 399b16a0c3d1f3a570d75af586f3dd7ec4642a3c  Branin  1318  N<DKLGPModel>   None
# 41152e59e664238a4b34aa547831be44a4f16eac  Branin  1369  N<DKLGPModel>   None
# 4b6b7ffff3bbdd53401ba8b9298404a0beeb983b  Branin  1366  N<DKLGPModel>   None
# 4c36181f8c4d1c371504bc0e3a9dcf62f12659ab  Branin  1296  N<DKLGPModel>   None
# 4cb09cc0a563ad74dfaddc5bd35c4f8e564304a6  Branin  1316  N<DKLGPModel>   None
# 4e134dbd60d01f7b96329fbfbfae72c96254a078  Branin  1363  N<DKLGPModel>   None
# 4e4bd2639c9fad55e4bcddf5ffcfb0b56343beab  Branin  1311  N<DKLGPModel>   None
# 4e82b4db7acb5ab86a9bb324f409976984c28b46  Branin  1372  N<DKLGPModel>   None
# 525bdb8a1c36e6abdde735409d5a2d59d7b37cb8  Branin  1340  N<DKLGPModel>   None
# 58806e6938bfb15fb35481c08c41be743ce2dbcf  Branin  1421  N<DKLGPModel>   None
# 58806e6938bfb15fb35481c08c41be743ce2dbcf  Branin  1414  N<DKLGPModel>   None
# 65b83901c70835bc1bb7069f44ee8e5603cca8de  Branin  1303  N<DKLGPModel>   None
# 65c77fb6867476eb0631d30eaffd6ece87ae9ef6  Branin  1304  N<DKLGPModel>   None
# 663910de7c4ac2efb40f6c4a3049a5b748fbe2c0  Branin  1383  N<DKLGPModel>   None
# 66b427bb0c64146ab3e7be2263850ae7e6979d28  Branin  1356  N<DKLGPModel>   None
# ...                                          ...   ...            ...    ...
# 7305c4d67716e95f52d87db40c8d34f2e60c20a0  Branin  1313  N<DKLGPModel>   None
# 773385daef7bc30af9cd6c532b1d34ba8a39ae86  Branin  1336  N<DKLGPModel>   None
# 8f987ce4f20499387e42fcccbfb0695999bc1221  Branin  1385  N<DKLGPModel>   None
# 9319e8a40f7423977d65aea1d58c89070f412570  Branin  1308  N<DKLGPModel>   None
# 961f61301c44057e106b2ddd96a8959e1f90b654  Branin  1378  N<DKLGPModel>   None
# 971f880db2017788381658b6e5f4d5116dc2c1b8  Branin  1298  N<DKLGPModel>   None
# 999f24501f74a8901780ba43edda5f65926d4d16  Branin  1338  N<DKLGPModel>   None
# 9fc7eddf843c67db91b7ec0c61185f0fbcf15ffc  Branin  1344  N<DKLGPModel>   None
# a08433e12a1b2110c576103227b1f9b33cb1e720  Branin  1307  N<DKLGPModel>   None
# ab7d75f55ec7840e458d40a431c41a63fe423835  Branin  1310  N<DKLGPModel>   None
# aeb6c4b2ca7aa972a121d5b0b99adf49f4c415a7  Branin  1370  N<DKLGPModel>   None
# aeddac54a75d071981c83679a8574d8b7f5f2d34  Branin  1342  N<DKLGPModel>   None
# af105b90ea04ae8e78d174881312073ece7820e0  Branin  1339  N<DKLGPModel>   None
# b63d0d547b49c59c1f3e94abb7d8311f136546f9  Branin  1341  N<DKLGPModel>   None
# ba2a84ccf4cf81f278e5ee1c63e5fd54a9204920  Branin  1309  N<DKLGPModel>   None
# bd03428bafe8a3afa8fd28c24e82f55bab889423  Branin  1300  N<DKLGPModel>   None
# c052205058ee2c7d7afdb322227d2730e8e06056  Branin  1380  N<DKLGPModel>   None
# c1e7cb2917bdcfe7baa32af37ffb3023badcc41c  Branin  1382  N<DKLGPModel>   None
# c642f0eaa382f1252000409683219a7d6870a608  Branin  1381  N<DKLGPModel>   None
# c85efaef5f3c67f5e6c63ef0fee47ca595102d48  Branin  1365  N<DKLGPModel>   None
# d843b232ad144b3a59eafa5688f0462b1f271deb  Branin  1354  N<DKLGPModel>   None
# d9fee56b88d0c9f96b46dcbb9a6c315a8b77aea3  Branin  1317  N<DKLGPModel>   None
# db1a75a9b6744424bce340b54f375acb9ea231fe  Branin  1314  N<DKLGPModel>   None
# dd65fb0a8981b95fd579311fb0997902dbc6768a  Branin  1384  N<DKLGPModel>   None
# eb5e37ec6a23900f3fecba05d84b946a736dac7e  Branin  1335  N<DKLGPModel>   None
# ec8a97568b7cbf6126fb23e166810648e4a0afd0  Branin  1351  N<DKLGPModel>   None
# ef2ad970e6b5af71306bce1b26a6ddd19a6b2f94  Branin  1312  N<DKLGPModel>   None
# f6fcc5f764c436b213612e093deda96a23d331c6  Branin  1367  N<DKLGPModel>   None
# f754177239020ab45a994b72545130ad707f243b  Branin  1350  N<DKLGPModel>   None
# fe7914956fd3a60181a937e4e1814dfd84879687  Branin  1355  N<DKLGPModel>   None
#
#                                                                         model_hash  \
# exp_hash
# 07b37aee9bfa261900cd66843c6322c2d30bbd16  3ebab13cc0ae39814346b9b7692bdc20ce3b240f
# 0ad8e6b72880d1908b3880e67a04adb6705161ed  a7dfa0e6e2332ade387e90726302fc90f8276c4c
# 0b1bb135cb3a3d9d286e7c487ae73e790883f044  7a27abe42d9eb3f1d3653381cee9547c26af6400
# 0b7c69191847ef6b6edfd1e70da97c1d4bac474b  7c42a68fc34a948b33d0ec1d681de24bc10a45e1
# 0d5c6b500626d7a4980dc5742f9232e8da270da4
# b63d0d547b49c59c1f3e94abb7d8311f136546f9  822e1c79a5339d85b52b1c3044a244dc1087866f
# ba2a84ccf4cf81f278e5ee1c63e5fd54a9204920  fb8b2aa93ad2f8310bb4c5c758ad48fc6a1a06b7
# bd03428bafe8a3afa8fd28c24e82f55bab889423  92753988c22305d92007420c33ed5e3cccdb0bd0
# c052205058ee2c7d7afdb322227d2730e8e06056  c54a2f5da8a3c2b37116264f2e704aaf106854c9
# c1e7cb2917bdcfe7baa32af37ffb3023badcc41c  7af6831ba23a12d2b1c8ae4180078f24be357c20
# c642f0eaa382f1252000409683219a7d6870a608  c54a2f5da8a3c2b37116264f2e704aaf106854c9
# c85efaef5f3c67f5e6c63ef0fee47ca595102d48  7a27abe42d9eb3f1d3653381cee9547c26af6400
# d843b232ad144b3a59eafa5688f0462b1f271deb  ebc5aefc6fd2a89d9c48e7b82f80fad1e33cb089
# d9fee56b88d0c9f96b46dcbb9a6c315a8b77aea3  3ebab13cc0ae39814346b9b7692bdc20ce3b240f
# db1a75a9b6744424bce340b54f375acb9ea231fe  8f2860bdaec840af43a8126f3769edee97fe953c
# dd65fb0a8981b95fd579311fb0997902dbc6768a  7af6831ba23a12d2b1c8ae4180078f24be357c20
# eb5e37ec6a23900f3fecba05d84b946a736dac7e  822e1c79a5339d85b52b1c3044a244dc1087866f
# ec8a97568b7cbf6126fb23e166810648e4a0afd0  a7dfa0e6e2332ade387e90726302fc90f8276c4c
# ef2ad970e6b5af71306bce1b26a6ddd19a6b2f94  8f2860bdaec840af43a8126f3769edee97fe953c
# f6fcc5f764c436b213612e093deda96a23d331c6  a6b3106a78190601cc918b54d6cba63ad60f9c05
# f754177239020ab45a994b72545130ad707f243b  a7dfa0e6e2332ade387e90726302fc90f8276c4c
# fe7914956fd3a60181a937e4e1814dfd84879687  ebc5aefc6fd2a89d9c48e7b82f80fad1e33cb089
#
#                                                           name  \
# exp_hash
# 07b37aee9bfa261900cd66843c6322c2d30bbd16  N<DKLGPModel> Branin
# 0ad8e6b72880d1908b3880e67a04adb6705161ed  N<DKLGPModel> Branin
# 0b1bb135cb3a3d9d286e7c487ae73e790883f044  N<DKLGPModel> Branin
# 0b7c69191847ef6b6edfd1e70da97c1d4bac474b  N<DKLGPModel> Branin
# 0d5c6b500626d7a4980dc5742f9232e8da270da4  N<DKLGPModel> Branin
# 0e4aed49465fc30b517c65ff81afa947801512c6  N<DKLGPModel> Branin
# 19e4bdbdf6669b737062f53bcb292c6d403a84fb  N<DKLGPModel> Branin
# 1b582ecaf251fcbdca006946c92305163a227d4b  N<DKLGPModel> Branin
# 1b974c18747c738149c9d9d74327d8c7673ecb69  N<DKLGPModel> Branin
# 1c2dac0621bcce6e8b92a5988e451cd405fb05a3  N<DKLGPModel> Branin
# 24675773c0c7107192e9686d2990d134346b17b8  N<DKLGPModel> Branin
# 26dd54cbade11dbcff5cc7b88dcf5da12d08ee79  N<DKLGPModel> Branin
# 278739c604338df2de93b500621b0977d81bc6e7  N<DKLGPModel> Branin
# 29be3c654f449413c919670026e88b21bbfe1d44  N<DKLGPModel> Branin
# 371cf8d77ab7d2db6e98a0bbf2b79b76bdb3490d  N<DKLGPModel> Branin
# 399b16a0c3d1f3a570d75af586f3dd7ec4642a3c  N<DKLGPModel> Branin
# 41152e59e664238a4b34aa547831be44a4f16eac  N<DKLGPModel> Branin
# 4b6b7ffff3bbdd53401ba8b9298404a0beeb983b  N<DKLGPModel> Branin
# 4c36181f8c4d1c371504bc0e3a9dcf62f12659ab  N<DKLGPModel> Branin
# 4cb09cc0a563ad74dfaddc5bd35c4f8e564304a6  N<DKLGPModel> Branin
# 4e134dbd60d01f7b96329fbfbfae72c96254a078  N<DKLGPModel> Branin
# 4e4bd2639c9fad55e4bcddf5ffcfb0b56343beab  N<DKLGPModel> Branin
# 4e82b4db7acb5ab86a9bb324f409976984c28b46  N<DKLGPModel> Branin
# 525bdb8a1c36e6abdde735409d5a2d59d7b37cb8  N<DKLGPModel> Branin
# 58806e6938bfb15fb35481c08c41be743ce2dbcf  N<DKLGPModel> Branin
# 58806e6938bfb15fb35481c08c41be743ce2dbcf  N<DKLGPModel> Branin
# 65b83901c70835bc1bb7069f44ee8e5603cca8de  N<DKLGPModel> Branin
# 65c77fb6867476eb0631d30eaffd6ece87ae9ef6  N<DKLGPModel> Branin
# 663910de7c4ac2efb40f6c4a3049a5b748fbe2c0  N<DKLGPModel> Branin
# 66b427bb0c64146ab3e7be2263850ae7e6979d28  N<DKLGPModel> Branin
# ...                                                        ...
# 7305c4d67716e95f52d87db40c8d34f2e60c20a0  N<DKLGPModel> Branin
# 773385daef7bc30af9cd6c532b1d34ba8a39ae86  N<DKLGPModel> Branin
# 8f987ce4f20499387e42fcccbfb0695999bc1221  N<DKLGPModel> Branin
# 9319e8a40f7423977d65aea1d58c89070f412570  N<DKLGPModel> Branin
# 961f61301c44057e106b2ddd96a8959e1f90b654  N<DKLGPModel> Branin
# 971f880db2017788381658b6e5f4d5116dc2c1b8  N<DKLGPModel> Branin
# 999f24501f74a8901780ba43edda5f65926d4d16  N<DKLGPModel> Branin
# 9fc7eddf843c67db91b7ec0c61185f0fbcf15ffc  N<DKLGPModel> Branin
# a08433e12a1b2110c576103227b1f9b33cb1e720  N<DKLGPModel> Branin
# ab7d75f55ec7840e458d40a431c41a63fe423835  N<DKLGPModel> Branin
# aeb6c4b2ca7aa972a121d5b0b99adf49f4c415a7  N<DKLGPModel> Branin
# aeddac54a75d071981c83679a8574d8b7f5f2d34  N<DKLGPModel> Branin
# af105b90ea04ae8e78d174881312073ece7820e0  N<DKLGPModel> Branin
# b63d0d547b49c59c1f3e94abb7d8311f136546f9  N<DKLGPModel> Branin
# ba2a84ccf4cf81f278e5ee1c63e5fd54a9204920  N<DKLGPModel> Branin
# bd03428bafe8a3afa8fd28c24e82f55bab889423  N<DKLGPModel> Branin
# c052205058ee2c7d7afdb322227d2730e8e06056  N<DKLGPModel> Branin
# c1e7cb2917bdcfe7baa32af37ffb3023badcc41c  N<DKLGPModel> Branin
# c642f0eaa382f1252000409683219a7d6870a608  N<DKLGPModel> Branin
# c85efaef5f3c67f5e6c63ef0fee47ca595102d48  N<DKLGPModel> Branin
# d843b232ad144b3a59eafa5688f0462b1f271deb  N<DKLGPModel> Branin
# d9fee56b88d0c9f96b46dcbb9a6c315a8b77aea3  N<DKLGPModel> Branin
# db1a75a9b6744424bce340b54f375acb9ea231fe  N<DKLGPModel> Branin
# dd65fb0a8981b95fd579311fb0997902dbc6768a  N<DKLGPModel> Branin
# eb5e37ec6a23900f3fecba05d84b946a736dac7e  N<DKLGPModel> Branin
# ec8a97568b7cbf6126fb23e166810648e4a0afd0  N<DKLGPModel> Branin
# ef2ad970e6b5af71306bce1b26a6ddd19a6b2f94  N<DKLGPModel> Branin
# f6fcc5f764c436b213612e093deda96a23d331c6  N<DKLGPModel> Branin
# f754177239020ab45a994b72545130ad707f243b  N<DKLGPModel> Branin
# fe7914956fd3a60181a937e4e1814dfd84879687  N<DKLGPModel> Branin
#
#                                                             result.WARNING  \
# exp_hash
# 07b37aee9bfa261900cd66843c6322c2d30bbd16                               NaN
# 0ad8e6b72880d1908b3880e67a04adb6705161ed                               NaN
# 0b1bb135cb3a3d9d286e7c487ae73e790883f044                    {'pred': True}
# 0b7c69191847ef6b6edfd1e70da97c1d4bac474b                               NaN
# 0d5c6b500626d7a4980dc5742f9232e8da270da4                               NaN
# 0e4aed49465fc30b517c65ff81afa947801512c6                    {'pred': True}
# 19e4bdbdf6669b737062f53bcb292c6d403a84fb                    {'pred': True}
# 1b582ecaf251fcbdca006946c92305163a227d4b                               NaN
# 1b974c18747c738149c9d9d74327d8c7673ecb69                               NaN
# 1c2dac0621bcce6e8b92a5988e451cd405fb05a3                               NaN
# 24675773c0c7107192e9686d2990d134346b17b8                               NaN
# 26dd54cbade11dbcff5cc7b88dcf5da12d08ee79                               NaN
# 278739c604338df2de93b500621b0977d81bc6e7                    {'pred': True}
# 29be3c654f449413c919670026e88b21bbfe1d44                               NaN
# 371cf8d77ab7d2db6e98a0bbf2b79b76bdb3490d                               NaN
# 399b16a0c3d1f3a570d75af586f3dd7ec4642a3c                               NaN
# 41152e59e664238a4b34aa547831be44a4f16eac                               NaN
# 4b6b7ffff3bbdd53401ba8b9298404a0beeb983b                               NaN
# 4c36181f8c4d1c371504bc0e3a9dcf62f12659ab                               NaN
# 4cb09cc0a563ad74dfaddc5bd35c4f8e564304a6                               NaN
# 4e134dbd60d01f7b96329fbfbfae72c96254a078                               NaN
# 4e4bd2639c9fad55e4bcddf5ffcfb0b56343beab                    {'pred': True}
# 4e82b4db7acb5ab86a9bb324f409976984c28b46                    {'pred': True}
# 525bdb8a1c36e6abdde735409d5a2d59d7b37cb8                               NaN
# 58806e6938bfb15fb35481c08c41be743ce2dbcf  {'pred': True, 'training': True}
# 58806e6938bfb15fb35481c08c41be743ce2dbcf  {'pred': True, 'training': True}
# 65b83901c70835bc1bb7069f44ee8e5603cca8de                    {'pred': True}
# 65c77fb6867476eb0631d30eaffd6ece87ae9ef6                    {'pred': True}
# 663910de7c4ac2efb40f6c4a3049a5b748fbe2c0                               NaN
# 66b427bb0c64146ab3e7be2263850ae7e6979d28                               NaN
# ...                                                                    ...
# 7305c4d67716e95f52d87db40c8d34f2e60c20a0                    {'pred': True}
# 773385daef7bc30af9cd6c532b1d34ba8a39ae
# ab7d75f55ec7840e458d40a431c41a63fe423835  scalable-smooth
# aeb6c4b2ca7aa972a121d5b0b99adf49f4c415a7  scalable-smooth
# aeddac54a75d071981c83679a8574d8b7f5f2d34  scalable-smooth
# af105b90ea04ae8e78d174881312073ece7820e0  scalable-smooth
# b63d0d547b49c59c1f3e94abb7d8311f136546f9  scalable-smooth
# ba2a84ccf4cf81f278e5ee1c63e5fd54a9204920  scalable-smooth
# bd03428bafe8a3afa8fd28c24e82f55bab889423  scalable-smooth
# c052205058ee2c7d7afdb322227d2730e8e06056  scalable-smooth
# c1e7cb2917bdcfe7baa32af37ffb3023badcc41c  scalable-smooth
# c642f0eaa382f1252000409683219a7d6870a608  scalable-smooth
# c85efaef5f3c67f5e6c63ef0fee47ca595102d48  scalable-smooth
# d843b232ad144b3a59eafa5688f0462b1f271deb  scalable-smooth
# d9fee56b88d0c9f96b46dcbb9a6c315a8b77aea3  scalable-smooth
# db1a75a9b6744424bce340b54f375acb9ea231fe  scalable-smooth
# dd65fb0a8981b95fd579311fb0997902dbc6768a  scalable-smooth
# eb5e37ec6a23900f3fecba05d84b946a736dac7e  scalable-smooth
# ec8a97568b7cbf6126fb23e166810648e4a0afd0  scalable-smooth
# ef2ad970e6b5af71306bce1b26a6ddd19a6b2f94  scalable-smooth
# f6fcc5f764c436b213612e093deda96a23d331c6  scalable-smooth
# f754177239020ab45a994b72545130ad707f243b  scalable-smooth
# fe7914956fd3a60181a937e4e1814dfd84879687  scalable-smooth
#
# [64 rows x 18 columns]

# %%
def get_M(r):
    SS_M = r.config.model.kwargs.feature_extractor_constructor.kwargs.get('M', None)
    if SS_M is not None:
        return SS_M
    return r.config.model.kwargs.model.kwargs.gp_kwargs.get('n_grid', None)

temp_df = aggregate_results(exps_rows_df)
temp_df['M'] = temp_df.apply(get_M, axis=1)
temp_df['noise'] = temp_df.apply(lambda r: r.config.obj_func.kwargs.get('noise', None), axis=1)
temp_df['double'] = temp_df.apply(lambda r: r.config.model.kwargs.model.kwargs.get('use_double_precision', False), axis=1)
temp_df['n_iter'] = temp_df.apply(lambda r: r.config.model.kwargs.model.kwargs.get('n_iter', False), axis=1)
temp_df['CG'] = temp_df.apply(lambda r: r.config.model.kwargs.model.kwargs.get('use_cg', False), axis=1)
temp_df['grid'] = temp_df.apply(lambda r: r.config.get('use_sample_grid', False), axis=1)
view_df(temp_df, indexes=['noise', 'double', 'n_iter', 'model', 'grid', 'M', 'CG', 'N'], cols=['result.rmse', 'result.max_err', 'result.time:training', 'result.time:pred']).sort_index()
# Out:
#                                                                       result.rmse  \
# noise double n_iter model         grid  M     CG    N       f
# 5.0   True   100    N<DKLGPModel> False 100.0 True  10000.0 Branin     104.206670
# NaN   False  50     N<DKLGPModel> False 50.0  True  100.0   Branin       6.127022
#                                                     1024.0  Branin       0.392870
#                                                     2500.0  Branin       0.412104
#                                                     10000.0 Branin       0.237181
#                                                     19600.0 Branin       0.120388
#                                         100.0 True  100.0   Branin       2.699344
#                                                     1024.0  Branin       0.363375
#                                                     2500.0  Branin       0.242419
#                                                     10000.0 Branin       0.101938
#                                                     19600.0 Branin       0.090640
#                                         140.0 True  100.0   Branin       2.352232
#                                                     1024.0  Branin       0.553134
#                                                     2500.0  Branin       0.192435
#                                                     1024.0  Branin             0.660
#                                                     2500.0  Branin             1.460
#                                                     10000.0 Branin            13.870
#              100    N<DKLGPModel> False 100.0 True  100.0   Branin             5.020
#                                                     1024.0  Branin            20.110
#                                                     2500.0  Branin           107.960
#                                                     10000.0 Branin           191.540
#                                         140.0 True  100.0   Branin            10.450
#                                                     1024.0  Branin            26.580
#                                                     2500.0  Branin           153.860
#                                                     10000.0 Branin           207.570
#                                         200.0 True  100.0   Branin            12.600
#                                                     1024.0  Branin            39.040
#                                         NaN   False 100.0   Branin             0.050
#                                                     1024.0  Branin             0.540
#                                                     2500.0  Branin             2.350
#                                                     10000.0 Branin            38.130
#                                               True  100.0   Branin             0.070
#                                                     1024.0  Branin             0.480
#                                                     2500.0  Branin             2.600
#                                                     10000.0 Branin            32.090
#
# [63 rows x 4 columns]

# %%
exp = select_experiment_with_rmse(temp_df, 0.101938)
exp.result['hyperparameters']
# Out:
# {'exp_hash': '19e4bdbdf6669b737062f53bcb292c6d403a84fb',
#  'gp_samples': 10000,
#  'gp_use_derivatives': False,
#  'model': {'kwargs': {'model': {'kwargs': {'eval_cg_tolerance': 1e-05,
#                                            'gp_kwargs': {'n_grid': 100},
#                                            'learning_rate': 0.1,
#                                            'max_cg_iter': 3000,
#                                            'n_iter': 50,
#                                            'nn_kwargs': {'layers': None},
#                                            'noise': None,
#                                            'precond_size': 10,
#                                            'use_cg': True},
#                                 'name': 'DKLGPModel'}},
#            'name': 'NormalizerModel'},
#  'model_compare': False,
#  'model_hash': '121664d3c54511ea1cd104b3402cc5abb87836f5',
#  'obj_func': {'name': 'Branin'},
#  'seed': 886693704,
#  'tag': 'scalable-smooth',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# {'lengthscale': {'py/object': 'numpy.ndarray',
#   'values': [[2.4087018966674805, 0.8830283880233765]],
#   'dtype': 'float32'},
#  'noise': 0.005595929455012083,
#  'outputscale': {'py/object': 'numpy.ndarray',
#   'values': 3.918612480163574,
#   'dtype': 'float32'}}

# %%
exp = select_experiment_with_rmse(temp_df, 101679.037397)
exp.result['hyperparameters']
# Out:
# {'exp_hash': '58806e6938bfb15fb35481c08c41be743ce2dbcf',
#  'gp_samples': 10000,
#  'gp_use_derivatives': False,
#  'model': {'kwargs': {'model': {'kwargs': {'eval_cg_tolerance': 1e-05,
#                                            'gp_kwargs': {'n_grid': 100},
#                                            'learning_rate': 0.1,
#                                            'max_cg_iter': 3000,
#                                            'n_iter': 100,
#                                            'nn_kwargs': {'layers': None},
#                                            'noise': None,
#                                            'precond_size': 10,
#                                            'use_cg': True},
#                                 'name': 'DKLGPModel'}},
#            'name': 'NormalizerModel'},
#  'model_compare': False,
#  'model_hash': 'a5f36f3965863ca249a5edd85e13f35e29c406df',
#  'obj_func': {'name': 'Branin'},
#  'seed': 910804746,
#  'tag': 'scalable-smooth',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# {'lengthscale': {'py/object': 'numpy.ndarray',
#   'values': [[2.8929831981658936, 0.29730162024497986]],
#   'dtype': 'float32'},
#  'noise': 0.0015558928716927767,
#  'outputscale': {'py/object': 'numpy.ndarray',
#   'values': 3.836301326751709,
#   'dtype': 'float32'}}

# %%
exp = select_experiment_with_rmse(temp_df, 0.093983)
exp.result['hyperparameters']
#exp.metrics['DKLGPModel.training.loss'].plot()
# Out:
# {'exp_hash': '6a0fd4cb234612a3c9fc0203f5c7ac0c75a9d65b',
#  'gp_samples': 10000,
#  'gp_use_derivatives': False,
#  'model': {'kwargs': {'model': {'kwargs': {'eval_cg_tolerance': 1e-05,
#                                            'gp_kwargs': {'n_grid': 140},
#                                            'learning_rate': 0.1,
#                                            'max_cg_iter': 3000,
#                                            'n_iter': 50,
#                                            'nn_kwargs': {'layers': None},
#                                            'noise': None,
#                                            'noise_lower_bound': 1e-10,
#                                            'precond_size': 10,
#                                            'use_cg': True,
#                                            'use_double_precision': True},
#                                 'name': 'DKLGPModel'}},
#            'name': 'NormalizerModel'},
#  'model_compare': False,
#  'model_hash': '7c42a68fc34a948b33d0ec1d681de24bc10a45e1',
#  'obj_func': {'name': 'Branin'},
#  'seed': 794591766,
#  'tag': 'scalable-smooth',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# {'lengthscale': {'py/object': 'numpy.ndarray',
#   'values': [[2.4234239813530025, 0.8880291250933462]],
#   'dtype': 'float64'},
#  'noise': 0.00546954151435403,
#  'outputscale': {'py/object': 'numpy.ndarray',
#   'values': 4.360226449770031,
#   'dtype': 'float64'}}

# %%
exp = select_experiment_with_rmse(temp_df, 120242.055071)
exp.result['hyperparameters']
#exp.metrics['DKLGPModel.training.loss'].plot()
# Out:
# {'exp_hash': '0b1bb135cb3a3d9d286e7c487ae73e790883f044',
#  'gp_samples': 10000,
#  'gp_use_derivatives': False,
#  'model': {'kwargs': {'model': {'kwargs': {'eval_cg_tolerance': 1e-05,
#                                            'gp_kwargs': {'n_grid': 140},
#                                            'learning_rate': 0.1,
#                                            'max_cg_iter': 3000,
#                                            'n_iter': 100,
#                                            'nn_kwargs': {'layers': None},
#                                            'noise': None,
#                                            'noise_lower_bound': 1e-10,
#                                            'precond_size': 10,
#                                            'use_cg': True,
#                                            'use_double_precision': True},
#                                 'name': 'DKLGPModel'}},
#            'name': 'NormalizerModel'},
#  'model_compare': False,
#  'model_hash': '7a27abe42d9eb3f1d3653381cee9547c26af6400',
#  'obj_func': {'name': 'Branin'},
#  'seed': 451635735,
#  'tag': 'scalable-smooth',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# {'lengthscale': {'py/object': 'numpy.ndarray',
#   'values': [[4.1703322569216805, 1.0206230750199647]],
#   'dtype': 'float64'},
#  'noise': 2.977149600649006e-05,
#  'outputscale': {'py/object': 'numpy.ndarray',
#   'values': 3.199482738277898,
#   'dtype': 'float64'}}

# %%
# Is 20000 => 8h reasonable?

# GPModel slow on server
# DKLGPModel sends warnings only on server
# DKLGPModel is slow in server

# DKLGPModel does not have good performance... Test performance and speed
    # Run GPytorch: CG, Exact
    # 

# Plot computational space
# Genz 1,2,3, branin, increasingoscillation
# Heston
# SSGP

# %% [markdown]
# # Financial

# %% [markdown]
# ## Heston (scalability)

# %% [markdown]
# ### Create

# %%
Ns = [10, 32, 50, 100, 140]

# gp = lambda N: {
#     'name': 'NormalizerModel',
#     'kwargs': {
#         'model': {
#             'name': 'GPModel',
#             'kwargs': dict(
#                 kernel=dict(
#                     name='GPyRBF',
#                     kwargs={'lengthscale': 0.6, 'ARD': True},
#                 ),
#                 noise_prior=None,
#                 do_optimize=True,
#                 num_mcmc=0,
#             )
#         },
#     }
# }
gp = lambda N: {
    'name': 'NormalizerModel',
    'kwargs': {
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 150,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'n_grid': None},
                'use_cg': False,
                #'use_double_precision': True,
                #'noise_lower_bound': 1e-10,
                'noise': None
            }
        }
    }
}

kissmodels = lambda N: {
    'name': 'NormalizerModel',
    'kwargs': {
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 150,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {'n_grid': N},
                'max_cg_iter': 1500,
                'precond_size': 10,
                #'use_double_precision': True,
                #'noise_lower_bound': 1e-10,
                'eval_cg_tolerance': 1e-8,
                'use_cg': True,
                'noise': None
            }
        }
    }
}

models = [gp, kissmodels]

for model in models:
    for N in Ns:
        run = execute(config_updates={
            'tag': 'heston',
            'obj_func': {
                'name': 'HestonOptionPricer',
            },
            'model': model(N),
            'gp_samples': N,
            'use_sample_grid': True,
        })

for d in range(1,10):
    run = execute(config_updates={
        'tag': 'heston',
        'obj_func': {
            'name': 'HestonOptionPricer',
        },
        'model': {
            'name': 'AdaptiveSparseGrid',
            'kwargs': dict(
                depth=d, 
                refinement_level=0,
                f_tol=1e-3,
            )
        },
    })
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="heston"\' \'obj_func={"name": "HestonOptionPricer"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 150, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}}}\' \'gp_samples=10\' \'use_sample_grid=True\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="heston"\' \'obj_func={"name": "HestonOptionPricer"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 150, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}}}\' \'gp_samples=32\' \'use_sample_grid=True\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="heston"\' \'obj_func={"name": "HestonOptionPricer"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 150, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}}}\' \'gp_samples=50\' \'use_sample_grid=True\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="heston"\' \'obj_func={"name": "HestonOptionPricer"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 150, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}}}\' \'gp_samples=100\' \'use_sample_grid=True\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="heston"\' \'obj_func={"name": "HestonOptionPricer"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 150, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": None}, "use_cg": False, "use_double_precision": True, "noise_lower_bound": 1e-10, "noise": None}}}}\' \'gp_samples=140\' \'use_sample_grid=True\'']
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="heston"\' \'obj_func={"name": "HestonOptionPricer"}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 150, "nn_kwargs": {"layers": None}, "gp_kwargs": {"n_grid": 10}, "max_cg_iter": 1500, "precond_size": 10, "use_double_precision": True, "noise_lower_bound": 1e-10, "eval_cg_tolerance": 1e-08, "use_cg": True, "noise": None}}}}\' \'gp_samples=10\' \'use_sample_grid=True\'']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-fa12ea2a8a51> in <module>
#      71             'model': model(N),
#      72             'gp_samples': N,
# ---> 73             'use_sample_grid': True,
#      74         })
#      75
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/runner.py in execute(*args, **kwargs)
#     197         func = notebook_run
#     198
# --> 199     return func(*args, **kwargs)
#     200
#     201
#
# ~/GoogleDrive/dtu/10-EPFL/thesis/thesis-code/runner.py in notebook_run_server(*args, **kwargs)
#     163     ssh_cmd = hpc_wrap(cmd)
#     164     print(ssh_cmd)
# --> 165     subprocess.call(ssh_cmd)
#     166
#     167
#
# ~/anaconda3/envs/lions/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     287     with Popen(*popenargs, **kwargs) as p:
#     288         try:
# --> 289             return p.wait(timeout=timeout)
#     290         except:
#     291             p.kill()
#
# ~/anaconda3/envs/lions/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1475                         if self.returncode is not None:
#    1476                             break  # Another thread waited.
# -> 1477                         (pid, sts) = self._try_wait(0)
#    1478                         # Check the pid and loop as waitpid has been known to
#    1479                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/envs/lions/lib/python3.6/subprocess.py in _try_wait(self, wait_flags)
#    1422             """All callers to this function MUST hold self._waitpid_lock."""
#    1423             try:
# -> 1424                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1425             except ChildProcessError:
#    1426                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ### View

# %%
df = get_df()
exps_rows_df = df[df["tag"] == "heston"].copy()
exps_rows_df = exps_rows_df[exps_rows_df['id'] > 1000]
exps_rows_df
# Out:
#                                               N   acq     bo  \
# exp_hash
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab    NaN  None  False
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab    NaN  None  False
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab    NaN  None  False
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140.0  None  False
# 1b970af1f452f08052e0e19820216100f08104ca   32.0  None  False
# 21094c2de0667145978fe16d5c58e6df57b4ebc8   10.0  None  False
# 269a5f1473591ed389b9f55af568973b0c47a4d7  100.0  None  False
# 33e7e518a37e5b488136de0c84cccad84aaf4783   32.0  None  False
# 33e7e518a37e5b488136de0c84cccad84aaf4783   32.0  None  False
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a   10.0  None  False
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  100.0  None  False
# 523010ba3d55fe47451728c096716272107961a5   50.0  None  False
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e   50.0  None  False
# 5ff62d37ce0713deba14afe34287571c46bdbc10  100.0  None  False
# 69b6c78f82937ed17c390e2d83be74a900006df4   10.0  None  False
# 7660a61b74530abda3900752295ab739fb9790b3   32.0  None  False
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47    NaN  None  False
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47    NaN  None  False
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47    NaN  None  False
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2    NaN  None  False
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2    NaN  None  False
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2    NaN  None  False
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56   10.0  None  False
# a0185eb40ed3c7b683f63f418dd3743f4881c95f   50.0  None  False
# a4edcfccc423075bfde573465a87392a739f7f63    NaN  None  False
# a4edcfccc423075bfde573465a87392a739f7f63    NaN  None  False
# a4edcfccc423075bfde573465a87392a739f7f63    NaN  None  False
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7   50.0  None  False
# b96eaa934cb371e9d6ea09521a200031c551420a  100.0  None  False
# b96eaa934cb371e9d6ea09521a200031c551420a  100.0  None  False
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc   10.0  None  False
# bdf58833ee83a173d858104761a720d14284701e   50.0  None  False
# bdf58833ee83a173d858104761a720d14284701e   50.0  None  False
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0b
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  HestonOptionPricer  1246
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  HestonOptionPricer  1264
# 523010ba3d55fe47451728c096716272107961a5  HestonOptionPricer  1241
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e  HestonOptionPricer  1262
# 5ff62d37ce0713deba14afe34287571c46bdbc10  HestonOptionPricer  1078
# 69b6c78f82937ed17c390e2d83be74a900006df4  HestonOptionPricer  1075
# 7660a61b74530abda3900752295ab739fb9790b3  HestonOptionPricer  1245
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47  HestonOptionPricer  1079
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47  HestonOptionPricer  1253
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47  HestonOptionPricer  1268
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2  HestonOptionPricer  1250
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2  HestonOptionPricer  1083
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2  HestonOptionPricer  1266
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56  HestonOptionPricer  1261
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  HestonOptionPricer  1247
# a4edcfccc423075bfde573465a87392a739f7f63  HestonOptionPricer  1252
# a4edcfccc423075bfde573465a87392a739f7f63  HestonOptionPricer  1082
# a4edcfccc423075bfde573465a87392a739f7f63  HestonOptionPricer  1267
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  HestonOptionPricer  1074
# b96eaa934cb371e9d6ea09521a200031c551420a  HestonOptionPricer  1273
# b96eaa934cb371e9d6ea09521a200031c551420a  HestonOptionPricer  1257
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  HestonOptionPricer  1077
# bdf58833ee83a173d858104761a720d14284701e  HestonOptionPricer  1258
# bdf58833ee83a173d858104761a720d14284701e  HestonOptionPricer  1272
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  HestonOptionPricer  1260
# f673cea7ad470d4692631aefadbe083c440e84a1  HestonOptionPricer  1076
# fb2b122d983995935710178c0b41be9500b5077b  HestonOptionPricer  1269
# fb2b122d983995935710178c0b41be9500b5077b  HestonOptionPricer  1255
#
#                                                        model model2  \
# exp_hash
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab  AdaptiveSparseGrid   None
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab  AdaptiveSparseGrid   None
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab  AdaptiveSparseGrid   None
# 12b4e4821b92a88b9844cb32642feb72402d0bdb       N<DKLGPModel>   None
# 1b970af1f452f08052e0e19820216100f08104ca       N<DKLGPModel>   None
# 21094c2de0667145978fe16d5c58e6df57b4ebc8       N<DKLGPModel>   None
# 269a5f1473591ed389b9f55af568973b0c47a4d7       N<DKLGPModel>   None
# 33e7e518a37e5b488136de0c84cccad84aaf4783       N<DKLGPModel>   None
# 33e7e518a37e5b488136de0c84cccad84aaf4783       N<DKLGPModel>   None
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a       N<DKLGPModel>   None
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f       N<DKLGPModel>   None
# 523010ba3d55fe47451728c096716272107961a5       N<DKLGPModel>   None
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e       N<DKLGPModel>   None
# 5ff62d37ce0713deba14afe34287571c46bdbc10       N<DKLGPModel>   None
# 69b6c78f82937ed17c390e2d83be74a900006df4       N<DKLGPModel>   None
# 7660a61b74530abda3900752295ab739fb9790b3       N<DKLGPModel>   None
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47  AdaptiveSparseGrid   None
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47  AdaptiveSparseGrid   None
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47  AdaptiveSparseGrid   None
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2  AdaptiveSparseGrid   None
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2  AdaptiveSparseGrid   None
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2  AdaptiveSparseGrid   None
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56       N<DKLGPModel>   None
# a0185eb40ed3c7b683f63f418dd3743f4881c95f       N<DKLGPModel>   None
# a4edcfccc423075bfde573465a87392a739f7f63  AdaptiveSparseGrid   None
# a4edcfccc423075bfde573465a87392a739f7f63  AdaptiveSparseGrid   None
# a4edcfccc423075bfde573465a87392a739f7f63  AdaptiveSparseGrid   None
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7       N<DKLGPModel>   None
# b96eaa934cb371e9d6ea09521a200031c551420a       N<DKLGPModel>   None
# b96eaa934cb371e9d6ea09521a200031c551420a       N<DKLGPModel>   None
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc          N<GPModel>   None
# bdf58833ee83a173d858104761a720d14284701e       N<DKLGPModel>   None
# bdf58833ee83a173d858104761a720d14284701e       N<DKLGPModel>   None
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0b
\
# exp_hash
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab  AdaptiveSparseGrid HestonOptionPricer
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab  AdaptiveSparseGrid HestonOptionPricer
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab  AdaptiveSparseGrid HestonOptionPricer
# 12b4e4821b92a88b9844cb32642feb72402d0bdb       N<DKLGPModel> HestonOptionPricer
# 1b970af1f452f08052e0e19820216100f08104ca       N<DKLGPModel> HestonOptionPricer
# 21094c2de0667145978fe16d5c58e6df57b4ebc8       N<DKLGPModel> HestonOptionPricer
# 269a5f1473591ed389b9f55af568973b0c47a4d7       N<DKLGPModel> HestonOptionPricer
# 33e7e518a37e5b488136de0c84cccad84aaf4783       N<DKLGPModel> HestonOptionPricer
# 33e7e518a37e5b488136de0c84cccad84aaf4783       N<DKLGPModel> HestonOptionPricer
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a       N<DKLGPModel> HestonOptionPricer
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f       N<DKLGPModel> HestonOptionPricer
# 523010ba3d55fe47451728c096716272107961a5       N<DKLGPModel> HestonOptionPricer
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e       N<DKLGPModel> HestonOptionPricer
# 5ff62d37ce0713deba14afe34287571c46bdbc10       N<DKLGPModel> HestonOptionPricer
# 69b6c78f82937ed17c390e2d83be74a900006df4       N<DKLGPModel> HestonOptionPricer
# 7660a61b74530abda3900752295ab739fb9790b3       N<DKLGPModel> HestonOptionPricer
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47  AdaptiveSparseGrid HestonOptionPricer
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47  AdaptiveSparseGrid HestonOptionPricer
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47  AdaptiveSparseGrid HestonOptionPricer
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2  AdaptiveSparseGrid HestonOptionPricer
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2  AdaptiveSparseGrid HestonOptionPricer
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2  AdaptiveSparseGrid HestonOptionPricer
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56       N<DKLGPModel> HestonOptionPricer
# a0185eb40ed3c7b683f63f418dd3743f4881c95f       N<DKLGPModel> HestonOptionPricer
# a4edcfccc423075bfde573465a87392a739f7f63  AdaptiveSparseGrid HestonOptionPricer
# a4edcfccc423075bfde573465a87392a739f7f63  AdaptiveSparseGrid HestonOptionPricer
# a4edcfccc423075bfde573465a87392a739f7f63  AdaptiveSparseGrid HestonOptionPricer
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7       N<DKLGPModel> HestonOptionPricer
# b96eaa934cb371e9d6ea09521a200031c551420a       N<DKLGPModel> HestonOptionPricer
# b96eaa934cb371e9d6ea09521a200031c551420a       N<DKLGPModel> HestonOptionPricer
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc          N<GPModel> HestonOptionPricer
# bdf58833ee83a173d858104761a720d14284701e       N<DKLGPModel> HestonOptionPricer
# bdf58833ee83a173d858104761a720d14284701e       N<DKLGPModel> HestonOptionPricer
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc       N<DKLGPModel> HestonOptionPricer
# f673cea7ad470d4692631aefadbe083c440e84a1       N<DKLGPModel> HestonOptionPricer
# fb2b122d983995935710178c0b41be9500b5077b       N<DKLGPModel> HestonOptionPricer
# fb2b122d983995935710178c0b41be9500b5077b       N<DKLGPModel> HestonOptionPricer
#
#                                                             result.WARNING  \
# exp_hash
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab                               NaN
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab                               NaN
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab                               NaN
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  {'pred': True, 'training': True}
# 1b970af1f452f08052e0e19820216100f08104ca                               NaN
# 21094c2de0667145978fe16d5c58e6df57b4ebc8                               NaN
# 269a5f1473591ed389b9f55af568973b0c47a4d7  {'pred': True, 'training': True}
# 33e7e518a37e5b488136de0c84cccad84aaf4783                               NaN
# 33e7e518a37e5b488136de0c84cccad84aaf4783                               NaN
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a                               NaN
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f                    {'pred': True}
# 523010ba3d55fe47451728c096716272107961a5                               NaN
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e                    {'pred': True}
# 5ff62d37ce0713deba14afe34287571c46bdbc10                {'training': True}
# 69b6c78f82937ed17c390e2d83be74a900006df4                               NaN
# 7660a61b74530abda3900752295ab739fb9790b3  {'pred': True, 'training': True}
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47                               NaN
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47                               NaN
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47                               NaN
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2                               NaN
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2                               NaN
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2                               NaN
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56                               NaN
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  {'pred': True, 'training': True}
# a4edcfccc423075bfde573465a87392a739f7f63                               NaN
# a4edcfccc423075bfde573465a87392a739f7f63                               NaN
# a4edcfccc423075bfde573465a87392a739f7f63                               NaN
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  {'pred': True, 'training': True}
# b96eaa934cb371e9d6ea09521a200031c551420a                               NaN
# b96eaa934cb371e9d6ea09521a200031c551420a                               NaN
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc                               NaN
# bdf58833ee83a173d858104761a720d14284701e                               NaN
# bdf58833ee83a173d858104761a720d14284701e                               NaN
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc                    {'pred': True}
# f673cea7ad470d4692631aefadbe083c440e84a1  {'pred': True, 'training': True}
# fb2b122d983995935710178c0b41be9500b5077b                               NaN
# fb2b122d983995935710178c0b41be9500b5077b                               NaN
#
#                                                                      result.hyperparameters  \
# exp_hash
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab                                                NaN
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab                                                NaN
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab                                                NaN
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 1b970af1f452f08052e0e19820216100f08104ca  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 269a5f1473591ed389b9f55af568973b0c47a4d7  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 33e7e518a37e5b488136de0c84cccad84aaf4783  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 33e7e518a37e5b488136de0c84cccad84aaf4783  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 523010ba3d55fe47451728c096716272107961a5  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 5ff62d37ce0713deba14afe34287571c46bdbc10  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 69b6c78f82937ed17c390e2d83be74a900006df4  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 7660a61b74530abda3900752295ab739fb9790b3  {'lengthscale': {'py/object': 'numpy.ndarray',...
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47                                                NaN
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47                                                NaN
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47                                                NaN
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2                                                NaN
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2                                                NaN
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2                                                NaN
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56  {'lengthscale': {'py/object': 'numpy.ndarray',...
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  {'lengthscale': {'py/object': 'numpy.ndarray',...
# a4edcfccc423075bfde573465a87392a739f7f63                                                NaN
# a4edcfccc423075bfde573465a87392a739f7f63                                                NaN
# a4edcfccc423075bfde573465a87392a739f7f63                                                NaN
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  {'lengthscale': {'py/object': 'numpy.ndarray',...
# b96eaa934cb371e9d6ea09521a200031c551420a  {'lengthscale': {'py/object': 'numpy.ndarray',...
# b96eaa934cb371e9d6ea09521a200031c551420a  {'lengthscale': {'py/object': 'numpy.ndarray',...
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  {'lengthscale': {'py/reduce': [{'py/object': '...
# bdf58833ee83a173d858104761a720d14284701e  {'lengthscale': {'py/object': 'numpy.ndarray',...
# bdf58833ee83a173d858104761a720d14284701e  {'lengthscale': {'py/object': 'numpy.ndarray',...
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  {'lengthscale': {'py/object': 'numpy.ndarray',...
# f673cea7ad470d4692631aefadbe083c440e84a1  {'lengthscale': {'py/object': 'numpy.ndarray',...
# fb2b122d983995935710178c0b41be9500b5077b  {'lengthscale': {'py/object': 'numpy.ndarray',...
# fb2b122d983995935710178c0b41be9500b5077b  {'lengthscale': {'py/object': 'numpy.ndarray',...
#
#                                           result.max_err  result.rmse  \
# exp_hash
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab        0.038383     0.006546
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab        0.038383     0.006546
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab        0.038383     0.006546
# 12b4e4821b92a88b9844cb32642feb72402d0bdb        0.000419     0.000159
# 1b970af1f452f08052e0e19820216100f08104ca        0.000313     0.000073
# 21094c2de0667145978fe16d5c58e6df57b4ebc8        0.000904     0.000169
# 269a5f1473591ed389b9f55af568973b0c47a4d7        0.001073     0.000499
# 33e7e518a37e5b488136de0c84cccad84aaf4783        0.000116     0.000029
# 33e7e518a37e5b488136de0c84cccad84aaf4783        0.000116     0.000029
# 4803c4cb7ca434fa04f764eb6994544c6a3c574
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab                  0.21  heston
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab                  0.22  heston
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab                  0.23  heston
# 12b4e4821b92a88b9844cb32642feb72402d0bdb              22499.83  heston
# 1b970af1f452f08052e0e19820216100f08104ca                102.68  heston
# 21094c2de0667145978fe16d5c58e6df57b4ebc8                  4.87  heston
# 269a5f1473591ed389b9f55af568973b0c47a4d7               8184.49  heston
# 33e7e518a37e5b488136de0c84cccad84aaf4783                 98.07  heston
# 33e7e518a37e5b488136de0c84cccad84aaf4783                102.41  heston
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a                 14.43  heston
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f               1045.35  heston
# 523010ba3d55fe47451728c096716272107961a5                637.06  heston
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e                361.45  heston
# 5ff62d37ce0713deba14afe34287571c46bdbc10              30090.78  heston
# 69b6c78f82937ed17c390e2d83be74a900006df4                 63.22  heston
# 7660a61b74530abda3900752295ab739fb9790b3                663.31  heston
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47                  1.25  heston
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47                  1.24  heston
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47                  1.23  heston
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2                  0.57  heston
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2                  0.60  heston
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2                  0.58  heston
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56                 25.86  heston
# a0185eb40ed3c7b683f63f418dd3743f4881c95f               2819.13  heston
# a4edcfccc423075bfde573465a87392a739f7f63                  0.89  heston
# a4edcfccc423075bfde573465a87392a739f7f63                  0.91  heston
# a4edcfccc423075bfde573465a87392a739f7f63                  0.90  heston
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7              11596.18  heston
# b96eaa934cb371e9d6ea09521a200031c551420a              27920.01  heston
# b96eaa934cb371e9d6ea09521a200031c551420a              27946.04  heston
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc                  0.72  heston
# bdf58833ee83a173d858104761a720d14284701e                684.92  heston
# bdf58833ee83a173d858104761a720d14284701e                628.63  heston
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc                259.47  heston
# f673cea7ad470d4692631aefadbe083c440e84a1               3831.34  heston
# fb2b122d983995935710178c0b41be9500b5077b                  2.73  heston
# fb2b122d983995935710178c0b41be9500b5077b                  3.92  heston

# %%
def get_M(r):
    SS_M = r.config.model.kwargs.model.kwargs.feature_extractor_constructor.kwargs.get('M', None)
    if SS_M is not None:
        return SS_M
    return r.config.model.kwargs.model.kwargs.gp_kwargs.get('n_grid', None)

temp_df = aggregate_results(exps_rows_df)
temp_df['M'] = temp_df.apply(get_M, axis=1)
temp_df['CG'] = temp_df.apply(lambda r: r.config.model.kwargs.model.kwargs.get('use_cg', False), axis=1)
temp_df['double'] = temp_df.apply(lambda r: r.config.model.kwargs.model.kwargs.get('use_double_precision', False), axis=1)
temp_df
# Out:
#                                                     N   acq     bo  \
# exp_hash                                 Ntemp
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab -1       NaN  None  False
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140   140.0  None  False
# 1b970af1f452f08052e0e19820216100f08104ca  32     32.0  None  False
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  10     10.0  None  False
# 269a5f1473591ed389b9f55af568973b0c47a4d7  100   100.0  None  False
# 33e7e518a37e5b488136de0c84cccad84aaf4783  32     32.0  None  False
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  10     10.0  None  False
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  100   100.0  None  False
# 523010ba3d55fe47451728c096716272107961a5  50     50.0  None  False
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e  50     50.0  None  False
# 5ff62d37ce0713deba14afe34287571c46bdbc10  100   100.0  None  False
# 69b6c78f82937ed17c390e2d83be74a900006df4  10     10.0  None  False
# 7660a61b74530abda3900752295ab739fb9790b3  32     32.0  None  False
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47 -1       NaN  None  False
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2 -1       NaN  None  False
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56  10     10.0  None  False
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  50     50.0  None  False
# a4edcfccc423075bfde573465a87392a739f7f63 -1       NaN  None  False
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  50     50.0  None  False
# b96eaa934cb371e9d6ea09521a200031c551420a  100   100.0  None  False
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  10     10.0  None  False
# bdf58833ee83a173d858104761a720d14284701e  50     50.0  None  False
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  32     32.0  None  False
# f673cea7ad470d4692631aefadbe083c440e84a1  32     32.0  None  False
# fb2b122d983995935710178c0b41be9500b5077b  10     10.0  None  False
#
#                                                                                            config  \
# exp_hash                                 Ntemp
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab -1     {'exp_hash': '02d48d6fd4aa9299a6d8087767dd31b5...
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140   {'exp_hash': '12b4e4821b92a88b9844cb32642feb72...
# 1b970af1f452f08052e0e19820216100f08104ca  32    {'exp_hash': '1b970af1f452f08052e0e19820216100...
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  10    {'exp_hash': '21094c2de0667145978fe16d5c58e6df...
# 269a5f1473591ed389b9f55af568973b0c47a4d7  100   {'exp_hash': '269a5f1473591ed389b9f55af568973b...
# 33e7e518a37e5b488136de0c84cccad84aaf4783  32    {'exp_hash': '33e7e518a37e5b488136de0c84cccad8...
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  10    {'exp_hash': '4803c4cb7ca434fa04f764eb6994544c...
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  100   {'exp_hash': '4c41a709f06becb9b2ba0dc1e6e9d407...
# 523010ba3d55fe47451728c096716272107961a5  50    {'exp_hash': '523010ba3d55fe47451728c096716272...
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e  50    {'exp_hash': '59dfecfe18a98461928c79bcbbba8d12...
# 5ff62d37ce0713deba14afe34287571c46bdbc10  100   {'exp_hash': '5ff62d37ce0713deba14afe34287571c...
# 69b6c78f82937ed17c390e2d83be74a900006df4  10    {'exp_hash': '69b6c78f82937ed17c390e2d83be74a9...
# 7660a61b74530abda3900752295ab739fb9790b3  32    {'exp_hash': '7660a61b74530abda3900752295ab739...
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47 -1     {'exp_hash': '7981c3b4b5c82e1d1e53c8d9e070a716...
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2 -1     {'exp_hash': '9a0fa7fa1bcf3bae7503ed046104761f...
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56  10    {'exp_hash': '9bde614f10eaa7453a00fe70c5bb0efb...
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  50    {'exp_hash': 'a0185eb40ed3c7b683f63f418dd3743f...
# a4edcfccc423075bfde573465a87392a739f7f63 -1     {'exp_hash': 'a4edcfccc423075bfde573465a87392a...
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  50    {'exp_hash': 'ae569c5a8f319ac78b27a95c6c35ca59...
# b96eaa934cb371e9d6ea09521a200031c551420a  100   {'exp_hash': 'b96eaa934cb371e9d6ea09521a200031...
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  10    {'exp_hash': 'ba882a8486afedc72cab4de8ef7247a3...
# bdf58833ee83a173d858104761a720d14284701e  50    {'exp_hash': 'bdf58833ee83a173d858104761a720d1...
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  32    {'exp_hash': 'f2c7c0bcc036eb8804378a559e6e6f9d...
# f673cea7ad470d4692631aefadbe083c440e84a1  32    {'exp_hash': 'f673cea7ad470d4692631aefadbe083c...
# fb2b122d983995935710178c0b41be9500b5077b  10    {'exp_hash': 'fb2b122d983995935710178c0b41be95...
#
#                                                                             exp  \
# exp_hash                                 Ntemp
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab -1     Experiment(id=1263, name=lions)
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140   Experiment(id=1249, name=lions)
# 1b970af1f452f08052e0e19820216100f08104ca  32    Experiment(id=1242, name=lions)
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  10    Experiment(id=1240, name=lions)
# 269a5f1473591ed389b9f55af568973b0c47a4d7  100   Experiment(id=1248, name=lions)
# 33e7e518a37e5b488136de0c84cccad84aaf4783  32    Experiment(id=1256, name=lions)
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  10    Experiment(id=1246, name=lions)
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  100   Experiment(id=1264, name=lions)
# 523010ba3d55fe47451728c096716272107961a5  50    Experiment(id=1241, name=lions)
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e  50    Experiment(id=1262, name=lions)
# 5ff62d37ce0713deba14afe34287571c46bdbc10  100   Experiment(id=1078, name=lions)
# 69b6c78f82937ed17c390e2d83be74a900006df4  10    Experiment(id=1075, name=lions)
# 7660a61b74530abda3900752295ab739fb9790b3  32    Experiment(id=1245, name=lions)
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47 -1     Experiment(id=1079, name=lions)
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2 -1     Experiment(id=1250, name=lions)
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56  10    Experiment(id=1261, name=lions)
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  50    Experiment(id=1247, name=lions)
# a4edcfccc423075bfde573465a87392a739f7f63 -1     Experiment(id=1252, name=lions)
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  50    Experiment(id=1074, name=lions)
# b96eaa934cb371e9d6ea09521a200031c551420a  100   Experiment(id=1273, name=lions)
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  10    Experiment(id=1077, name=lions)
# bdf58833ee83a173d858104761a720d14284701e  50    Experiment(id=1258, name=lions)
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  32    Experiment(id=1260, name=lions)
# f673cea7ad470d4692631aefadbe083c440e84a1  32    Experiment(id=1076, name=lions)
# fb2b122d983995935710178c0b41be9500b5077b  10    Experiment(id=1269, name=lions)
#
#                                                                  f    id  \
# exp_hash                                 Ntemp
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab -1     HestonOptionPricer  1263
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140   HestonOptionPricer  1249
# 1b970af1f452f08052e0e19820216100f08104ca  32    HestonOptionPricer  1242
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  10    HestonOptionPricer  1240
# 269a5f1473591ed389b9f55af568973b0c47a4d7  100   HestonOptionPricer  1248
# 33e7e518a37e5b488136de0c84cccad84aaf4783  32    HestonOptionPricer  1256
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  10    HestonOptionPricer  1246
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  100   HestonOptionPricer  1264
# 523010ba3d55fe47451728c096716272107961a5  50    HestonOptionPricer  1241
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e  50    HestonOptionPricer  1262
# 5ff62d37ce0713deba14afe34287571c46bdbc10  100   HestonOptionPricer  1078
# 69b6c78f82937ed17c390e2d83be74a900006df4  10    HestonOptionPricer  1075
# 7660a61b74530abda3900752295ab739fb9790b3  32    HestonOptionPricer  1245
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47 -1     HestonOptionPricer  1079
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2 -1     HestonOptionPricer  1250
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56  10    HestonOptionPricer  1261
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  50    HestonOptionPricer  1247
# a4edcfccc423075bfde573465a87392a739f7f63 -1     HestonOptionPricer  1252
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  50    HestonOptionPricer  1074
# b96eaa934cb371e9d6ea09521a200031c551420a  100   HestonOptionPricer  1273
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  10    HestonOptionPricer  1077
# bdf58833ee83a173d858104761a720d14284701e  50    HestonOptionPricer  1258
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  32    HestonOptionPricer  1260
# f673cea7ad470d4692631aefadbe083c440e84a1  32    HestonOptionPricer  1076
# fb2b122d983995935710178c0b41be9500b5077b  10    HestonOptionPricer  1269
#
#                                                              model model2  \
# exp_hash                                 Ntemp
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab -1     AdaptiveSparseGrid   None
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140        N<DKLGPModel>   None
# 1b970af1f452f08052e0e19820216100f08104ca  32         N<DKLGPModel>   None
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  10         N<DKLGPModel>   None
# 269a5f1473591ed389b9f55af568973b0c47a4d7  100        N<DKLGPModel>   None
# 33e7e518a37e5b488136de0c84cccad84aaf4783  32         N<DKLGPModel>   None
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  10         N<DKLGPModel>   None
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  100        N<DKLGPModel>   None
# 523010ba3d55fe47451728c096716272107961a5  50         N<DKLGPModel>   None
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e  50         N<DKLGPModel>   None
# 5ff62d37ce0713deba14afe34287571c46bdbc10  100        N<DKLGPModel>   None
# 69b6c78f82937ed17c390e2d83be74a900006df4  10         N<DKLGPModel>   None
# 7660a61b74530abda3900752295ab739fb9790b3  32         N<DKLGPModel>   None
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47 -1     AdaptiveSparseGrid   None
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2 -1     AdaptiveSparseGrid   None
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56  10         N<DKLGPModel>   None
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  50         N<DKLGPModel>   None
# a4edcfccc423075bfde573465a87392a739f7f63 -1     AdaptiveSparseGrid   None
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  50         N<DKLGPModel>   None
# b96eaa934cb371e9d6ea09521a200031c551420a  100        N<DKLGPModel>   None
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  10            N<GPModel>   None
# bdf58833ee83a173d858104761a720d14284701e  50         N<DKLGPModel>   None
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  32         N<DKLGPModel>   None
# f673cea7ad470d4692631aefadbe083c440e84a1  32         N<DKLGPModel>   None
# fb2b122d983995935710178c0b41be9500b5077b  10         N<DKLGPModel>   None
#
#                                                                               model_hash  \
# exp_hash                                 Ntemp
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab -1     343eb7677405c3b446a70733706f28ef97e6e053
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140   f0a235a7e138303c413aa093a770dd7296ce74f0
# 1b970af1f452f08052e0e19820216100f08104ca  32    db91661a2f98e0d760245cade196bc8776a00f1a
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  10
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  50    {'pred': True, 'training': True}
# b96eaa934cb371e9d6ea09521a200031c551420a  100                                NaN
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  10                                 NaN
# bdf58833ee83a173d858104761a720d14284701e  50                                 NaN
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  32                      {'pred': True}
# f673cea7ad470d4692631aefadbe083c440e84a1  32    {'pred': True, 'training': True}
# fb2b122d983995935710178c0b41be9500b5077b  10                                 NaN
#
#                                                                            result.hyperparameters  \
# exp_hash                                 Ntemp
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab -1                                                   NaN
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140   {'lengthscale': {'py/object': 'numpy.ndarray',...
# 1b970af1f452f08052e0e19820216100f08104ca  32    {'lengthscale': {'py/object': 'numpy.ndarray',...
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  10    {'lengthscale': {'py/object': 'numpy.ndarray',...
# 269a5f1473591ed389b9f55af568973b0c47a4d7  100   {'lengthscale': {'py/object': 'numpy.ndarray',...
# 33e7e518a37e5b488136de0c84cccad84aaf4783  32    {'lengthscale': {'py/object': 'numpy.ndarray',...
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  10    {'lengthscale': {'py/object': 'numpy.ndarray',...
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  100   {'lengthscale': {'py/object': 'numpy.ndarray',...
# 523010ba3d55fe47451728c096716272107961a5  50    {'lengthscale': {'py/object': 'numpy.ndarray',...
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e  50    {'lengthscale': {'py/object': 'numpy.ndarray',...
# 5ff62d37ce0713deba14afe34287571c46bdbc10  100   {'lengthscale': {'py/object': 'numpy.ndarray',...
# 69b6c78f82937ed17c390e2d83be74a900006df4  10    {'lengthscale': {'py/object': 'numpy.ndarray',...
# 7660a61b74530abda3900752295ab739fb9790b3  32    {'lengthscale': {'py/object': 'numpy.ndarray',...
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47 -1                                                   NaN
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2 -1                                                   NaN
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56  10    {'lengthscale': {'py/object': 'numpy.ndarray',...
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  50    {'lengthscale': {'py/object': 'numpy.ndarray',...
# a4edcfccc423075bfde573465a87392a739f7f63 -1                                                   NaN
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  50    {'lengthscale': {'py/object': 'numpy.ndarray',...
# b96eaa934cb371e9d6ea09521a200031c551420a  100   {'lengthscale': {'py/object': 'numpy.ndarray',...
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  10    {'lengthscale': {'py/reduce': [{'py/object': '...
# bdf58833ee83a173d858104761a720d14284701e  50    {'lengthscale': {'py/object': 'numpy.ndarray',...
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  32    {'lengthscale': {'py/object': 'numpy.ndarray',...
# f673cea7ad470d4692631aefadbe083c440e84a1  32    {'lengthscale': {'py/object': 'numpy.ndarray',...
# fb2b122d983995935710178c0b41be9500b5077b  10    {'lengthscale': {'py/object': 'numpy.ndarray',...
#
#                                                result.max_err  result.rmse  \
# exp_hash                                 Ntemp
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab -1          0.038383     0.006546
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140        0.000419     0.000159
# 1b970af1f452f08052e0e19820216100f08104ca  32         0.000313     0.000073
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  10         0.000904     0.000169
# 269a5f1473591ed389b9f55af568973b0c47a4d7  100        0.001073     0.000499
# 33e7e518a37e5b488136de0c84cccad84aaf4783  32         0.000116     0.000029
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  10         0.001863     0.000297
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  100     1292.156266   492.977507
# 523010ba3d55fe47451728c096716272107961a5  50         0.000340     0.000063
# 59dfecfe18a98461928c79bcbbba8d129e90dd3e  50       203.339435    97.711957
# 5ff62d37ce0713deba14afe34287571c46bdbc10  100        0.001197     0.000415
# 69b6c78f82937ed17c390e2d83be74a900006df4  10         0.000882     0.000166
# 7660a61b74530abda3900752295ab739fb9790b3  32         0.070072     0.047414
# 7981c3b4b5c82e1d1e53c8d9e070a71629a3bb47 -1          0.002008     0.000361
# 9a0fa7fa1bcf3bae7503ed046104761f976458d2 -1          0.014595     0.004169
# 9bde614f10eaa7453a00fe70c5bb0efb0937ed56  10         0.002717     0.000386
# a0185eb40ed3c7b683f63f418dd3743f4881c95f  50         0.000665     0.000290
# a4edcfccc423075bfde573465a87392a739f7f63 -1          0.005747     0.001198
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  50         0.005283     0.003109
# b96eaa934cb371e9d6ea09521a200031c551420a  100        0.000060     0.000014
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  10         0.000307     0.000070
# bdf58833ee83a173d858104761a720d14284701e  50         0.000087     0.000022
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  32       397.699832   152.766584
# f673cea7ad470d4692631aefadbe083c440e84a1  32         0.017293     0.010254
# fb2b122d983995935710178c0b41be9500b5077b  10         0.000322     0.000071
#
#                                                 result.time:pred  \
# exp_hash                                 Ntemp
# 02d48d6fd4aa9299a6d8087767dd31b56bc952ab -1             0.023333
# 12b4e4821b92a88b9844cb32642feb72402d0bdb  140         194.540000
# 1b970af1f452f08052e0e19820216100f08104ca  32            0.930000
# 21094c2de0667145978fe16d5c58e6df57b4ebc8  10            0.070000
# 269a5f1473591ed389b9f55af568973b0c47a4d7  100         113.140000
# 33e7e518a37e5b488136de0c84cccad84aaf4783  32            0.605000
# 4803c4cb7ca434fa04f764eb6994544c6a3c574a  10            0.990000
# 4c41a709f06becb9b2ba0dc1e6e9d4071917477f  
# a4edcfccc423075bfde573465a87392a739f7f63 -1       NaN  False   False
# ae569c5a8f319ac78b27a95c6c35ca5904abb5b7  50    100.0   True   False
# b96eaa934cb371e9d6ea09521a200031c551420a  100     NaN  False    True
# ba882a8486afedc72cab4de8ef7247a3de0bd5dc  10      NaN  False   False
# bdf58833ee83a173d858104761a720d14284701e  50      NaN  False    True
# f2c7c0bcc036eb8804378a559e6e6f9dd54bc0bc  32     32.0   True    True
# f673cea7ad470d4692631aefadbe083c440e84a1  32     64.0   True   False
# fb2b122d983995935710178c0b41be9500b5077b  10      NaN  False    True
#
# [25 rows x 21 columns]

# %%
view_df(temp_df, indexes=['double', 'CG', 'model', 'M', 'N'], cols=['result.rmse', 'result.max_err', 'result.time:training']).sort_index()
# Out:
#                                                                 result.rmse  \
# double CG    model              M     N     f
# False  False AdaptiveSparseGrid NaN   NaN   HestonOptionPricer     0.006546
#                                             HestonOptionPricer     0.000361
#                                             HestonOptionPricer     0.004169
#                                             HestonOptionPricer     0.001198
#              N<DKLGPModel>      NaN   10.0  HestonOptionPricer     0.000169
#                                       32.0  HestonOptionPricer     0.000073
#                                       50.0  HestonOptionPricer     0.000063
#              N<GPModel>         NaN   10.0  HestonOptionPricer     0.000070
#        True  N<DKLGPModel>      10.0  10.0  HestonOptionPricer     0.000297
#                                 20.0  10.0  HestonOptionPricer     0.000166
#                                 32.0  32.0  HestonOptionPricer     0.047414
#                                 50.0  50.0  HestonOptionPricer     0.000290
#                                 64.0  32.0  HestonOptionPricer     0.010254
#                                 100.0 50.0  HestonOptionPricer     0.003109
#                                       100.0 HestonOptionPricer     0.000499
#                                 140.0 140.0 HestonOptionPricer     0.000159
#                                 200.0 100.0 HestonOptionPricer     0.000415
# True   False N<DKLGPModel>      NaN   10.0  HestonOptionPricer     0.000071
#                                       32.0  HestonOptionPricer     0.000029
#                                       50.0  HestonOptionPricer     0.000022
#                                       100.0 HestonOptionPricer     0.000014
#        True  N<DKLGPModel>      10.0  10.0  HestonOptionPricer     0.000386
#                                 32.0  32.0  HestonOptionPricer   152.766584
#                                 50.0  50.0  HestonOptionPricer    97.711957
#                                 100.0 100.0 HestonOptionPricer   492.977507
#
#                                                                 result.max_err  \
# double CG    model              M     N     f
# False  False AdaptiveSparseGrid NaN   NaN   HestonOptionPricer        0.038383
#                                             HestonOptionPricer        0.002008
#                                             HestonOptionPricer        0.014595
#                                             HestonOptionPricer        0.005747
#              N<DKLGPModel>      NaN   10.0  HestonOptionPricer        0.000904
#                                       32.0  HestonOptionPricer        0.000313
#                                       50.0  HestonOptionPricer        0.000340
#              N<GPModel>         NaN   10.0  HestonOptionPricer        0.000307
#        True  N<DKLGPModel>      10.0  10.0  HestonOptionPricer        0.001863
#                                 20.0  10.0  HestonOptionPricer        0.000882
#                                 32.0  32.0  HestonOptionPricer        0.070072
#                                 50.0  50.0  HestonOptionPricer        0.000665
#                                 64.0  32.0  HestonOptionPricer        0.017293
#                                 100.0 50.0  HestonOptionPricer        0.005283
#                                       100.0 HestonOptionPricer        0.001073
#                                 140.0 140.0 HestonOptionPricer        0.000419
#                                 200.0 100.0 HestonOptionPricer        0.001197
# True   False N<DKLGPModel>      NaN   10.0  HestonOptionPricer        0.000322
#                                       32.0  HestonOptionPricer        0.000116
#                                       50.0  HestonOptionPricer        0.000087
#                                       100.0 HestonOptionPricer        0.000060
#        True  N<DKLGPModel>      10.0  10.0  HestonOptionPricer        0.002717
#                                 32.0  32.0  HestonOptionPricer      397.699832
#                                 50.0  50.0  HestonOptionPricer      203.339435
#                                 100.0 100.0 HestonOptionPricer     1292.156266
#
#                                                                 result.time:training
# double CG    model              M     N     f
# False  False AdaptiveSparseGrid NaN   NaN   HestonOptionPricer              0.220000
#                                             HestonOptionPricer              1.240000
#                                             HestonOptionPricer              0.583333
#                                             HestonOptionPricer              0.900000
#              N<DKLGPModel>      NaN   10.0  HestonOptionPricer              4.870000
#                                       32.0  HestonOptionPricer            102.680000
#                                       50.0  HestonOptionPricer            637.060000
#              N<GPModel>         NaN   10.0  HestonOptionPricer              0.720000
#        True  N<DKLGPModel>      10.0  10.0  HestonOptionPricer             14.430000
#                                 20.0  10.0  HestonOptionPricer             63.220000
#                                 32.0  32.0  HestonOptionPricer            663.310000
#                                 50.0  50.0  HestonOptionPricer           2819.130000
#                                 64.0  32.0  HestonOptionPricer           3831.340000
#                                 100.0 50.0  HestonOptionPricer          11596.180000
#                                       100.0 HestonOptionPricer           8184.490000
#                                 140.0 140.0 HestonOptionPricer          22499.830000
#                                 200.0 100.0 HestonOptionPricer          30090.780000
# True   False N<DKLGPModel>      NaN   10.0  HestonOptionPricer              3.325000
#                                       32.0  HestonOptionPricer            100.240000
#                                       50.0  HestonOptionPricer            656.775000
#                                       100.0 HestonOptionPricer          27933.025000
#        True  N<DKLGPModel>      10.0  10.0  HestonOptionPricer             25.860000
#                                 32.0  32.0  HestonOptionPricer            259.470000
#                                 50.0  50.0  HestonOptionPricer            361.450000
#                                 100.0 100.0 HestonOptionPricer           1045.350000

# %%
exp.to_dict()['captured_out']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-2c9f9ddf8b6b> in <module>
# ----> 1 exp.to_dict()['captured_out']
#
# NameError: name 'exp' is not defined

# %%
exp = select_experiment_with_rmse(temp_df, 0.000070)
exp.metrics['DKLGPModel.training.loss'].plot()
# Out:
# {'exp_hash': 'ba882a8486afedc72cab4de8ef7247a3de0bd5dc',
#  'gp_samples': 10,
#  'gp_use_derivatives': False,
#  'model': {'kwargs': {'model': {'kwargs': {'do_optimize': True,
#                                            'kernel': {'kwargs': {'ARD': True,
#                                                                  'lengthscale': 0.6},
#                                                       'name': 'GPyRBF'},
#                                            'noise_prior': None,
#                                            'num_mcmc': 0},
#                                 'name': 'GPModel'}},
#            'name': 'NormalizerModel'},
#  'model_compare': False,
#  'model_hash': '899fd518bfb4e2a4aea784806654e0748ddf636e',
#  'obj_func': {'name': 'HestonOptionPricer'},
#  'seed': 273087622,
#  'tag': 'heston',
#  'use_sample_grid': True,
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-aeffd6c0a6af> in <module>
#       1 exp = select_experiment_with_rmse(temp_df, 0.000070)
# ----> 2 exp.metrics['DKLGPModel.training.loss'].plot()
#
# KeyError: 'DKLGPModel.training.loss'

# %% [markdown]
# ## FORTRAN

# %% [markdown]
# ### Create

# %%
settings.SERVER_DEST = 'epfl'
settings.MODE = settings.MODES.SERVER

Ds = [2, 4, 8, 12, 20]

for D in Ds:
    # DKL Matern
    run = execute(config_updates=normalize_config({
        'tag': 'EconomicModel4',
        'obj_func': {
            'name': 'EconomicModel',
            'kwargs': {'D': D, 'output_policy': 1},
        },
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 2000,
                'nn_kwargs': {'layers': [100, 50, 2], 'output_activation': False},
                'gp_kwargs': {
                    'kernel': {'name': 'MaternKernel'}
                },
                'max_cg_iter': 30000,
                'precond_size': 20,
                'use_cg': True,
                'noise': None,
                'use_double_precision': True,
                'noise_lower_bound': 1e-8,
                'train_eval_cg_tolerance': 1e-4,
                'eval_cg_tolerance': 1e-6,
            }
        }
    }))
    
    # DKL SE
    run = execute(config_updates=normalize_config({
        'tag': 'EconomicModel4',
        'obj_func': {
            'name': 'EconomicModel',
            'kwargs': {'D': D, 'output_policy': 1},
        },
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 2000,
                'nn_kwargs': {'layers': [100, 50, 2], 'output_activation': False},
                'max_cg_iter': 30000,
                'precond_size': 20,
                'use_cg': True,
                'noise': None,
                'use_double_precision': True,
                'noise_lower_bound': 1e-8,
                'train_eval_cg_tolerance': 1e-4,
                'eval_cg_tolerance': 1e-6,
            }
        }
    }))
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 2, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71623\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 2, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71624\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 4, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71625\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 4, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71626\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 8, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71627\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 8, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71628\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 12, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71629\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 12, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71630\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 20, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71631\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 20, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 2], "output_activation": False}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71632\n'

# %%
settings.MODE = settings.MODES.SERVER
                                                                                                         
# DKL pretrained (early stopping with validation...)
# DKL (+ KISS-GP)
# GP
# DNN + BLR
# (SG would not work)

Ds = [2, 4, 8, 12, 20]

for D in Ds:
    # LASSO
    run = execute(config_updates=normalize_config({
        'tag': 'EconomicModel4',
        'obj_func': {
            'name': 'EconomicModel',
            'kwargs': {'D': D, 'output_policy': 1},
        },
        'model': {
            'name': 'LASSO',
        }
    }))

    # Linear
    run = execute(config_updates=normalize_config({
        'tag': 'EconomicModel4',
        'obj_func': {
            'name': 'EconomicModel',
            'kwargs': {'D': D, 'output_policy': 1},
        },
        'model': {
            'name': 'LinearFromFeatureExtractor',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 400,
                'nn_kwargs': {'layers': [100,50,5]},
            }
        }
    }))

    # BLR
    run = execute(config_updates=normalize_config({
        'tag': 'EconomicModel4',
        'obj_func': {
            'name': 'EconomicModel',
            'kwargs': {'D': D, 'output_policy': 1},
        },
        'model': {
            'name': 'DNNBLR',
            'kwargs': {
                'do_pretrain': False,
                #'pretrain_n_iter': 200,
                'learning_rate': 0.1,
                'n_iter': 2000,
                'nn_kwargs': {'layers': [100, 50, 50]},
                'max_cg_iter': 30000,
                'precond_size': 20,
                'use_cg': True,
                'noise': None,
                'use_double_precision': True,
                'noise_lower_bound': 1e-8,
                'train_eval_cg_tolerance': 1e-4,
                'eval_cg_tolerance': 1e-6,
            }
        }
    }))

    # GP
    run = execute(config_updates=normalize_config({
        'tag': 'EconomicModel4',
        'obj_func': {
            'name': 'EconomicModel',
            'kwargs': {'D': D, 'output_policy': 1},
        },
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 2000,
                'nn_kwargs': {'layers': None},
                'max_cg_iter': 30000,
                'precond_size': 20,
                'use_cg': True,
                'noise': None,
                'use_double_precision': True,
                'noise_lower_bound': 1e-8,
                'train_eval_cg_tolerance': 1e-4,
                'eval_cg_tolerance': 1e-6,
            }
        }
    }))

    # Matern
    run = execute(config_updates=normalize_config({
        'tag': 'EconomicModel4',
        'obj_func': {
            'name': 'EconomicModel',
            'kwargs': {'D': D, 'output_policy': 1},
        },
        'model': {
            'name': 'DKLGPModel',
            'kwargs': {
                'learning_rate': 0.1,
                'n_iter': 2000,
                'nn_kwargs': {'layers': None},
                'gp_kwargs': {
                    'kernel': {'name': 'MaternKernel'}
                },
                'max_cg_iter': 30000,
                'precond_size': 20,
                'use_cg': True,
                'noise': None,
                'use_double_precision': True,
                'noise_lower_bound': 1e-8,
                'train_eval_cg_tolerance': 1e-4,
                'eval_cg_tolerance': 1e-6,
            }
        }
    }))
# Out:
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 2, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LASSO"}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71633\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 2, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LinearFromFeatureExtractor", "kwargs": {"learning_rate": 0.1, "n_iter": 400, "nn_kwargs": {"layers": [100, 50, 5]}}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71634\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 2, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DNNBLR", "kwargs": {"do_pretrain": False, "learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 50]}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71635\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 2, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71636\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 2, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71637\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 4, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LASSO"}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71638\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 4, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LinearFromFeatureExtractor", "kwargs": {"learning_rate": 0.1, "n_iter": 400, "nn_kwargs": {"layers": [100, 50, 5]}}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71639\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 4, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DNNBLR", "kwargs": {"do_pretrain": False, "learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 50]}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71640\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 4, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71641\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 4, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71642\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 8, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LASSO"}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71643\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 8, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LinearFromFeatureExtractor", "kwargs": {"learning_rate": 0.1, "n_iter": 400, "nn_kwargs": {"layers": [100, 50, 5]}}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71644\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 8, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DNNBLR", "kwargs": {"do_pretrain": False, "learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 50]}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71645\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 8, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71646\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 8, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71647\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 12, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LASSO"}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71648\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 12, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LinearFromFeatureExtractor", "kwargs": {"learning_rate": 0.1, "n_iter": 400, "nn_kwargs": {"layers": [100, 50, 5]}}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71649\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 12, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DNNBLR", "kwargs": {"do_pretrain": False, "learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 50]}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71650\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 12, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71651\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 12, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71652\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 20, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LASSO"}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71653\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 20, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "LinearFromFeatureExtractor", "kwargs": {"learning_rate": 0.1, "n_iter": 400, "nn_kwargs": {"layers": [100, 50, 5]}}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71654\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 20, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DNNBLR", "kwargs": {"do_pretrain": False, "learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": [100, 50, 50]}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71655\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 20, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71656\n'
# ['ssh', 'simba', 'cd mthesis; sbatch hpc.sh \'python\' \'runner.py\' \'with\' \'tag="final--EconomicModel4"\' \'obj_func={"name": "EconomicModel", "kwargs": {"D": 20, "output_policy": 1}}\' \'model={"name": "NormalizerModel", "kwargs": {"model": {"name": "DKLGPModel", "kwargs": {"learning_rate": 0.1, "n_iter": 2000, "nn_kwargs": {"layers": None}, "gp_kwargs": {"kernel": {"name": "MaternKernel"}}, "max_cg_iter": 30000, "precond_size": 20, "use_cg": True, "noise": None, "use_double_precision": True, "noise_lower_bound": 1e-08, "train_eval_cg_tolerance": 0.0001, "eval_cg_tolerance": 1e-06}}, "normalize_input": True, "normalize_output": True}}\'']
# b'Submitted batch job 71657\n'

# %% [markdown]
# ### View

# %%
exps_rows_df = get_df(**{'config.tag': "final--EconomicModel4"})
exps_rows_df

# %%
def get_M(r):
    SS_M = r.config.model.kwargs.feature_extractor_constructor.kwargs.get('M', None)
    if SS_M is not None:
        return SS_M
    SGPR_M = r.config.model.kwargs.gp_kwargs.get('inducing_points', None)
    if SGPR_M is not None:
        return SGPR_M
    return r.config.model.kwargs.gp_kwargs.get('n_grid', None)

temp_df = aggregate_results(exps_rows_df)

temp_df['n_iter'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.get('n_iter'), axis=1)
temp_df['layers'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.nn_kwargs.get('layers'), axis=1)
temp_df['layers'] = temp_df.apply(lambda row: tuple(row.layers) if row.layers is not None else (), axis=1)
temp_df['kernel'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.gp_kwargs.kernel.get('name', 'RBFKernel'), axis=1)
temp_df['norm'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.nn_kwargs.get('normalize_output', True), axis=1)
temp_df['t_tol'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.get('train_eval_cg_tolerance', 1.0), axis=1)
temp_df['act'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.nn_kwargs.get('activation', 'relu'), axis=1)
temp_df['out_act'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.nn_kwargs.get('output_activation', False), axis=1)

temp_df['f.D'] = temp_df.apply(lambda r: r.config.obj_func.kwargs.D, axis=1)
temp_df['M'] = temp_df.apply(get_M, axis=1)
temp_df['double'] = temp_df.apply(lambda r: r.config.model.kwargs.model.kwargs.get('use_double_precision', False), axis=1)
pd.options.display.max_rows = 999
view_df(temp_df, indexes=['f.D', 'model', 'layers', 'kernel', 'n_iter', 'M', 'double', 'norm', 't_tol', 'out_act'], cols=['result.rmse', 'result.max_err', 'result.time:training']).sort_index()

# %% [markdown]
# ### Play

# %%
exp = select_experiment_with_rmse(temp_df, 0.000033)
exp.metrics['DKLGPModel.training.loss'].plot()
exp.result['hyperparameters']
# Out:
# {'exp_hash': '10a7ed0b74da8d4986d7b42a2cb2e02b73e6f7ad',
#  'gp_use_derivatives': False,
#  'gpu': False,
#  'model': {'kwargs': {'model': {'kwargs': {'eval_cg_tolerance': 1e-06,
#                                            'gp_kwargs': {'kernel': {'name': 'MaternKernel'}},
#                                            'learning_rate': 0.1,
#                                            'max_cg_iter': 30000,
#                                            'n_iter': 2000,
#                                            'nn_kwargs': {'layers': [100, 50, 5],
#                                                          'output_activation': True},
#                                            'noise': None,
#                                            'noise_lower_bound': 1e-08,
#                                            'precond_size': 20,
#                                            'train_eval_cg_tolerance': 0.0001,
#                                            'use_cg': True,
#                                            'use_double_precision': True},
#                                 'name': 'DKLGPModel'},
#                       'normalize_input': True,
#                       'normalize_output': True},
#            'name': 'NormalizerModel'},
#  'model_compare': False,
#  'model_hash': '9655d01f0c5d20113d4b67ec074c06e372047230',
#  'obj_func': {'kwargs': {'D': 2, 'output_policy': 1}, 'name': 'EconomicModel'},
#  'seed': 766643381,
#  'tag': 'final--EconomicModel3',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# {'lengthscale': {'py/object': 'numpy.ndarray',
#   'values': [[3.06796626096867,
#     2.8264439835712665,
#     10.45002337457571,
#     12.302702978712556,
#     6.2016666341805164]],
#   'dtype': 'float64'},
#  'noise': 1.3382320215531553e-08,
#  'outputscale': {'py/object': 'numpy.ndarray',
#   'values': 2.471237492049343,
#   'dtype': 'float64'}}

# %%
# 4D
exp = select_experiment_with_rmse(temp_df, 0.004054)
exp.metrics['DKLGPModel.training.loss'].plot()
exp.result['hyperparameters']
# Out:
# {'exp_hash': '344844b6f10f22c778001e4fc7ed6f4e5723cfb8',
#  'gp_use_derivatives': False,
#  'gpu': False,
#  'model': {'kwargs': {'model': {'kwargs': {'eval_cg_tolerance': 1e-06,
#                                            'learning_rate': 0.1,
#                                            'max_cg_iter': 30000,
#                                            'n_iter': 400,
#                                            'nn_kwargs': {'layers': [100,
#                                                                     50,
#                                                                     5]},
#                                            'noise': None,
#                                            'noise_lower_bound': 1e-08,
#                                            'precond_size': 20,
#                                            'train_eval_cg_tolerance': 0.0001,
#                                            'use_cg': True,
#                                            'use_double_precision': True},
#                                 'name': 'DKLGPModel'},
#                       'normalize_input': True,
#                       'normalize_output': True},
#            'name': 'NormalizerModel'},
#  'model_compare': False,
#  'model_hash': 'fde8664094f52566c09c162736059f2d62807aa7',
#  'obj_func': {'kwargs': {'D': 4, 'output_policy': 1}, 'name': 'EconomicModel'},
#  'seed': 99418221,
#  'tag': 'final--EconomicModel2',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# {'lengthscale': {'py/object': 'numpy.ndarray',
#   'values': [[3.1024001077638603,
#     4.38211273729097,
#     3.256288921221362,
#     2.503192400661212,
#     2.2267717114254055]],
#   'dtype': 'float64'},
#  'noise': 1.875819989926394e-06,
#  'outputscale': {'py/object': 'numpy.ndarray',
#   'values': 6.528968804774333,
#   'dtype': 'float64'}}

# %%
temp_df[temp_df['kernel'] == 'MaternKernel'][['id', 'exp', 'layers', 'f.D', 'result.rmse']].sort_values('f.D')
# Out:
#                                                   id  \
# exp_hash                                 Ntemp
# 804f9c375544f8e79f69f72646ca273eae74b037 -1     2530
# 10a7ed0b74da8d4986d7b42a2cb2e02b73e6f7ad -1     2498
# bed025d6e2f1151851fe0223f1ddb4fa178135f2 -1     2501
# 1dfe224bd71b4bf269bddc656a9978cd7bd33be6 -1     2540
# 24618a4c46dc8bfe6c9407a5ad5e857a51920866 -1     2550
# 65a8ef35c78be7e2e28fce48b540764c9699c3d5 -1     2560
# 770fe5ec9d7b49a72cf846f7ca356a0de1c97963 -1     2542
# 74e307aa898925be13c0220900020ecbcb7f65c2 -1     2508
# bd4c727f61d5074da620ab3fdc25c48aa5980ece -1     2552
# 8bb5550ea16509964ba663cdb96eb224b2d9b7a8 -1     2562
# 430fc9bc0f0e1db7d4442a61e94de12d8a82e7c4 -1     2532
# d5c84596efff70248ccca930599476f15bb33f20 -1     2505
# 3c738bcda3792d71ff7907b3ab20ccd12288d030 -1     2554
# 728e2cf265082c782fba2ff67ad1891daf1adb77 -1     2544
# 32d2bff43edca1db3acf52fd98765083a5bf0ba7 -1     2512
# ddaa9183375928c1c30743fed451daefa34e245c -1     2515
# 8b71b8a459ff734dcbd8ddacd9cde276edffaf0c -1     2564
# 5fe84faeaabe5e176f04dc9e50ff3d81a16de773 -1     2534
# b038460db04150b125138e0669858e6db57bf17f -1     2519
# 068b8de7955270f4d84bd3f0d7c0a96bafed396c -1     2536
# 7984e3ba8b44bd16e2c354082de65b2f2ba15a8a -1     2546
# 6ced196e01775c84f98164732067fed41db99cb6 -1     2556
# 13532632cf34570479c7c329acfc8a84b78b1c62 -1     2522
# e1005d7e517842821711859085c398e8d449a576 -1     2566
# 9780bb741d0748f64cc7686a5ccea735d8bbfd2f -1     2548
# 9b09f8a94e01b5e8cf4d826de78bfdeb2c76ac55 -1     2526
# b95711a33347d54022297f336ae7206daa28b90f -1     2529
# 09342887c51efa031bc3678ef9bfc9bc298b8286 -1     2568
# d73ea5133e9e69c4bf2fc09478b433712e09ec46 -1     2558
# 9623745a3571168e4ae192b503a4bdc34b223cdb -1     2538
#
#                                                                             exp  \
# exp_hash                                 Ntemp
# 804f9c375544f8e79f69f72646ca273eae74b037 -1     Experiment(id=2530, name=lions)
# 10a7ed0b74da8d4986d7b42a2cb2e02b73e6f7ad -1     Experiment(id=2498, name=lions)
# bed025d6e2f1151851fe0223f1ddb4fa178135f2 -1     Experiment(id=2501, name=lions)
# 1dfe224bd71b4bf269bddc656a9978cd7bd33be6 -1     Experiment(id=2540, name=lions)
# 24618a4c46dc8bfe6c9407a5ad5e857a51920866 -1     Experiment(id=2550, name=lions)
# 65a8ef35c78be7e2e28fce48b540764c9699c3d5 -1     Experiment(id=2560, name=lions)
# 770fe5ec9d7b49a72cf846f7ca356a0de1c97963 -1     Experiment(id=2542, name=lions)
# 74e307aa898925be13c0220900020ecbcb7f65c2 -1     Experiment(id=2508, name=lions)
# bd4c727f61d5074da620ab3fdc25c48aa5980ece -1     Experiment(id=2552, name=lions)
# 8bb5550ea16509964ba663cdb96eb224b2d9b7a8 -1     Experiment(id=2562, name=lions)
# 430fc9bc0f0e1db7d4442a61e94de12d8a82e7c4 -1     Experiment(id=2532, name=lions)
# d5c84596efff70248ccca930599476f15bb33f20 -1     Experiment(id=2505, name=lions)
# 3c738bcda3792d71ff7907b3ab20ccd12288d030 -1     Experiment(id=2554, name=lions)
# 728e2cf265082c782fba2ff67ad1891daf1adb77 -1     Experiment(id=2544, name=lions)
# 32d2bff43edca1db3acf52fd98765083a5bf0ba7 -1     Experiment(id=2512, name=lions)
# ddaa9183375928c1c30743fed451daefa34e245c -1     Experiment(id=2515, name=lions)
# 8b71b8a459ff734dcbd8ddacd9cde276edffaf0c -1     Experiment(id=2564, name=lions)
# 5fe84faeaabe5e176f04dc9e50ff3d81a16de773 -1     Experiment(id=2534, name=lions)
# b038460db04150b125138e0669858e6db57bf17f -1     Experiment(id=2519, name=lions)
# 068b8de7955270f4d84bd3f0d7c0a96bafed396c -1     Experiment(id=2536, name=lions)
# 7984e3ba8b44bd16e2c354082de65b2f2ba15a8a -1     Experiment(id=2546, name=lions)
# 6ced196e01775c84f98164732067fed41db99cb6 -1     Experiment(id=2556, name=lions)
# 13532632cf34570479c7c329acfc8a84b78b1c62 -1     Experiment(id=2522, name=lions)
# e1005d7e517842821711859085c398e8d449a576 -1     Experiment(id=2566, name=lions)
# 9780bb741d0748f64cc7686a5ccea735d8bbfd2f -1     Experiment(id=2548, name=lions)
# 9b09f8a94e01b5e8cf4d826de78bfdeb2c76ac55 -1     Experiment(id=2526, name=lions)
# b95711a33347d54022297f336ae7206daa28b90f -1     Experiment(id=2529, name=lions)
# 09342887c51efa031bc3678ef9bfc9bc298b8286 -1     Experiment(id=2568, name=lions)
# d73ea5133e9e69c4bf2fc09478b433712e09ec46 -1     Experiment(id=2558, name=lions)
# 9623745a3571168e4ae192b503a4bdc34b223cdb -1     Experiment(id=2538, name=lions)
#
#                                                            layers  f.D  \
# exp_hash                                 Ntemp
# 804f9c375544f8e79f69f72646ca273eae74b037 -1      (100, 50, 50, 5)    2
# 10a7ed0b74da8d4986d7b42a2cb2e02b73e6f7ad -1          (100, 50, 5)    2
# bed025d6e2f1151851fe0223f1ddb4fa178135f2 -1                    ()    2
# 1dfe224bd71b4bf269bddc656a9978cd7bd33be6 -1      (100, 50, 50, 5)    2
# 24618a4c46dc8bfe6c9407a5ad5e857a51920866 -1     (1000, 50, 50, 5)    2
# 65a8ef35c78be7e2e28fce48b540764c9699c3d5 -1          (100, 50, 2)    2
# 770fe5ec9d7b49a72cf846f7ca356a0de1c97963 -1      (100, 50, 50, 5)    4
# 74e307aa898925be13c0220900020ecbcb7f65c2 -1                    ()    4
# bd4c727f61d5074da620ab3fdc25c48aa5980ece -1     (1000, 50, 50, 5)    4
# 8bb5550ea16509964ba663cdb96eb224b2d9b7a8 -1          (100, 50, 2)    4
# 430fc9bc0f0e1db7d4442a61e94de12d8a82e7c4 -1      (100, 50, 50, 5)    4
# d5c84596efff70248ccca930599476f15bb33f20 -1          (100, 50, 5)    4
# 3c738bcda3792d71ff7907b3ab20ccd12288d030 -1     (1000, 50, 50, 5)    8
# 728e2cf265082c782fba2ff67ad1891daf1adb77 -1      (100, 50, 50, 5)    8
# 32d2bff43edca1db3acf52fd98765083a5bf0ba7 -1          (100, 50, 5)    8
# ddaa9183375928c1c30743fed451daefa34e245c -1                    ()    8
# 8b71b8a459ff734dcbd8ddacd9cde276edffaf0c -1          (100, 50, 2)    8
# 5fe84faeaabe5e176f04dc9e50ff3d81a16de773 -1      (100, 50, 50, 5)    8
# b038460db04150b125138e0669858e6db57bf17f -1          (100, 50, 5)   12
# 068b8de7955270f4d84bd3f0d7c0a96bafed396c -1      (100, 50, 50, 5)   12
# 7984e3ba8b44bd16e2c354082de65b2f2ba15a8a -1      (100, 50, 50, 5)   12
# 6ced196e01775c84f98164732067fed41db99cb6 -1     (1000, 50, 50, 5)   12
# 13532632cf34570479c7c329acfc8a84b78b1c62 -1                    ()   12
# e1005d7e517842821711859085c398e8d449a576 -1          (100, 50, 2)   12
# 9780bb741d0748f64cc7686a5ccea735d8bbfd2f -1      (100, 50, 50, 5)   20

#                                            'learning_rate': 0.1,
#                                            'max_cg_iter': 30000,
#                                            'n_iter': 500,
#                                            'nn_kwargs': {'layers': [100,
#                                                                     50,
#                                                                     5]},
#                                            'noise': None,
#                                            'noise_lower_bound': 1e-08,
#                                            'precond_size': 20,
#                                            'train_eval_cg_tolerance': 0.0001,
#                                            'use_cg': True,
#                                            'use_double_precision': True},
#                                 'name': 'DKLGPModel'},
#                       'normalize_input': True,
#                       'normalize_output': True},
#            'name': 'NormalizerModel'},
#  'model_compare': False,
#  'model_hash': 'c774e02b895069865badd56dda35357f47e060b1',
#  'obj_func': {'kwargs': {'D': 4, 'output_policy': 1}, 'name': 'EconomicModel'},
#  'seed': 311005037,
#  'tag': 'final--EconomicModel2',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
#
# {'hyperparameters': {'lengthscale': {'py/object': 'numpy.ndarray', 'values': [[10.02105119684058, 6.443970065153659, 8.392681896955807, 8.305546267494027, 4.444476686475305]], 'dtype': 'float64'}, 'noise': 5.95252849157908e-07, 'outputscale': {'py/object': 'numpy.ndarray', 'values': 3.831423154498243, 'dtype': 'float64'}}, 'mae': 0.0012420339268647857, 'max_err': 0.006095188690395492, 'mnlp': -200.7496966076792, 'nmse': 0.0003127674035667302, 'rmse': 0.0018776090614671206, 'time:pred': 0.44999999999999574, 'time:training': 39.870000000000005}

# %%
path = os.path.join(settings.MODEL_SNAPSHOTS_DIR, 'b46c7594468fce8d77334f41070f1b384bef3577', '300')
model = DKLGPModel.load(path)
#model = NormalizerModel(model=model)

f = EconomicModel.from_config({'D': 2, 'output_policy': 1})

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(f.X_train[:,0], f.X_train[:,1], f.Y_train[:,0])
# Out:
# training on 2250 data points of dim 2

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(f.X_test[:,0], f.X_test[:,1], f.Y_test[:,0])

# %%
XY, X, Y = construct_2D_grid(np.array([[0,1],[0,1]]))
Z = call_function_on_grid(model.get_features, XY)
O = call_function_on_grid(model.get_mean, XY)[...,0]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.contourf(X,Y,O, 100)
ax.set_title('Feature mapping')
# Out:
# predicting 2500 points using 2250 training points
# Text(0.5, 0.92, 'Feature mapping')

# %%
exp = select_experiment_with_rmse(temp_df, 0.001878)
exp.metrics['DKLGPModel.training.loss'].plot()
exp.result['hyperparameters']
# Out:
# {'exp_hash': '3fa46eecd788cb4b49b7af1abbff167ce67db703',
#  'gp_use_derivatives': False,
#  'gpu': False,
#  'model': {'kwargs': {'model': {'kwargs': {'eval_cg_tolerance': 1e-06,
#                                            'gp_kwargs': {'kernel': {'name': 'MaternKernel'}},
#                                            'learning_rate': 0.1,
#                                            'max_cg_iter': 30000,
#                                            'n_iter': 500,
#                                            'nn_kwargs': {'layers': [100,
#                                                                     50,
#                                                                     5]},
#                                            'noise': None,
#                                            'noise_lower_bound': 1e-08,
#                                            'precond_size': 20,
#                                            'train_eval_cg_tolerance': 0.0001,
#                                            'use_cg': True,
#                                            'use_double_precision': True},
#                                 'name': 'DKLGPModel'},
#                       'normalize_input': True,
#                       'normalize_output': True},
#            'name': 'NormalizerModel'},
#  'model_compare': False,
#  'model_hash': 'c774e02b895069865badd56dda35357f47e060b1',
#  'obj_func': {'kwargs': {'D': 4, 'output_policy': 1}, 'name': 'EconomicModel'},
#  'seed': 311005037,
#  'tag': 'final--EconomicModel2',
#  'verbosity': {'bo_show_iter': 30, 'plot': False}}
# {'lengthscale': {'py/object': 'numpy.ndarray',
#   'values': [[10.02105119684058,
#     6.443970065153659,
#     8.392681896955807,
#     8.305546267494027,
#     4.444476686475305]],
#   'dtype': 'float64'},
#  'noise': 5.95252849157908e-07,
#  'outputscale': {'py/object': 'numpy.ndarray',
#   'values': 3.831423154498243,
#   'dtype': 'float64'}}

# %% [markdown]
# ### Figures & Tables

# %%
def create_display_df(col='result.rmse', NAME = "RMSE"):
    format_ = "{:.5f}"

    exps_rows_df2 = exps_rows_df[exps_rows_df.apply(lambda row: not row.config.model.kwargs.model.kwargs.nn_kwargs.get('output_activation', False), axis=1)]
    #exps_rows_df2 = exps_rows_df2.drop('0a31ca2184fd7b83576577372ff358d724dbc030',axis=0)
    temp_df = aggregate_result_std(exps_rows_df2, col=col, format=format_)

    temp_df['n_iter'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.get('n_iter'), axis=1)
    temp_df['layers'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.nn_kwargs.get('layers'), axis=1)
    temp_df['layers'] = temp_df.apply(lambda row: tuple(row.layers) if row.layers is not None else (), axis=1)
    temp_df['kernel'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.gp_kwargs.kernel.get('name', 'RBFKernel'), axis=1)
    temp_df['norm'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.nn_kwargs.get('normalize_output', True), axis=1)
    temp_df['t_tol'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.get('train_eval_cg_tolerance', 1.0), axis=1)
    temp_df['act'] = temp_df.apply(lambda row: row.config.model.kwargs.model.kwargs.nn_kwargs.get('activation', 'relu'), axis=1)

    temp_df['f.D'] = temp_df.apply(lambda r: r.config.obj_func.kwargs.D, axis=1)
    temp_df['double'] = temp_df.apply(lambda r: r.config.model.kwargs.model.kwargs.get('use_double_precision', False), axis=1)

    def get_display_name(r):
        name = r.config.model.kwargs.model.name
        kernel = r['kernel']
        if name == 'DKLGPModel':
            if r['layers'] != ():
                if kernel == 'MaternKernel':
                    return 'DKL (Matern)'
                elif kernel == 'RBFKernel':
                    return 'DKL (SE)'
            elif kernel == 'MaternKernel':
                return 'GP (Matern)'
            elif kernel == 'RBFKernel':
                return 'GP (SE)'
        if name == 'LinearFromFeatureExtractor':
            return 'DNN'
        return name

    # Summaries taps
    temp_df['Model'] = temp_df.apply(get_display_name, axis=1)
    temp_df['f'] = temp_df['f.D']
    temp_df[NAME] = temp_df[f'{col}.describe']

    display_df = view_df(temp_df, indexes=['Model'], cols=[NAME], f_as_col=True).sort_index()
    return display_df

# %%
display_df = create_display_df(col='result.rmse')

# %%
baseline_df = create_baseline(temp_df)
baseline_df['Model'] = 'Mean'
baseline_df[NAME] = baseline_df['result.rmse'].map(format_.format).map(lambda str_: f"{str_} ± {format_.format(0.0)}")
baseline_df = view_df(baseline_df, indexes=['Model'], cols=[NAME], f_as_col=True).sort_index()
#baseline_df = baseline_df.droplevel(0, axis=1)

full_display_df = display_df
#full_display_df = pd.concat((display_df, baseline_df))
full_display_df = full_display_df.reindex(['GP (Matern)', 'GP (SE)', 'DKL (Matern)', 'DKL (SE)', 'DNNBLR', 'DNN', 'LASSO'])
full_display_df.columns = full_display_df.columns.rename("Dimensionality", level=1)
full_display_df
# Out:
#                              RMSE                                        \
# Dimensionality                 2                  4                  8
# Model
# GP (Matern)     0.00002 ± 0.00000  0.00104 ± 0.00000  0.00101 ± 0.00000
# GP (SE)         0.00007 ± 0.00000  0.00329 ± 0.00059  0.00143 ± 0.00001
# DKL (Matern)    0.00003 ± 0.00000  0.00143 ± 0.00005  0.00139 ± 0.00008
# DKL (SE)        0.00482 ± 0.00675  0.00120 ± 0.00000  0.00167 ± 0.00018
# DNNBLR          0.00004 ± 0.00000  0.00124 ± 0.00021  0.00161 ± 0.00032
# DNN             0.00007 ± 0.00001  0.00231 ± 0.00029  0.00312 ± 0.00005
# LASSO           0.00805 ± 0.00000  0.10609 ± 0.00000  0.10138 ± 0.00000
#
#
# Dimensionality                 12                 20
# Model
# GP (Matern)     0.00115 ± 0.00001  0.00074 ± 0.00000
# GP (SE)         0.00178 ± 0.00000  0.00097 ± 0.00000
# DKL (Matern)    0.00131 ± 0.00004  0.00113 ± 0.00019
# DKL (SE)        0.05298 ± 0.07306  0.00113 ± 0.00003
# DNNBLR          0.00185 ± 0.00011  0.00154 ± 0.00006
# DNN             0.00504 ± 0.00048  0.00428 ± 0.00014
# LASSO           0.10534 ± 0.00000  0.08017 ± 0.00000

# %%
# \label{table:policy-rmse}
save_table(full_display_df.to_latex(escape=False, bold_rows=True, column_format='lccccc', multicolumn=True, multicolumn_format='c'), 'policy-rmse')
# Out:
# \begin{tabular}{lccccc}
# \toprule
# {} & \multicolumn{5}{c}{RMSE} \\
# \textbf{Dimensionality} &                 2  &                 4  &                 8  &                 12 &                 20 \\
# \textbf{Model       } &                    &                    &                    &                    &                    \\
# \midrule
# \textbf{GP (Matern) } &  0.00002 ± 0.00000 &  0.00104 ± 0.00000 &  0.00101 ± 0.00000 &  0.00115 ± 0.00001 &  0.00074 ± 0.00000 \\
# \textbf{GP (SE)     } &  0.00007 ± 0.00000 &  0.00329 ± 0.00059 &  0.00143 ± 0.00001 &  0.00178 ± 0.00000 &  0.00097 ± 0.00000 \\
# \textbf{DKL (Matern)} &  0.00003 ± 0.00000 &  0.00143 ± 0.00005 &  0.00139 ± 0.00008 &  0.00131 ± 0.00004 &  0.00113 ± 0.00019 \\
# \textbf{DKL (SE)    } &  0.00482 ± 0.00675 &  0.00120 ± 0.00000 &  0.00167 ± 0.00018 &  0.05298 ± 0.07306 &  0.00113 ± 0.00003 \\
# \textbf{DNNBLR      } &  0.00004 ± 0.00000 &  0.00124 ± 0.00021 &  0.00161 ± 0.00032 &  0.00185 ± 0.00011 &  0.00154 ± 0.00006 \\
# \textbf{DNN         } &  0.00007 ± 0.00001 &  0.00231 ± 0.00029 &  0.00312 ± 0.00005 &  0.00504 ± 0.00048 &  0.00428 ± 0.00014 \\
# \textbf{LASSO       } &  0.00805 ± 0.00000 &  0.10609 ± 0.00000 &  0.10138 ± 0.00000 &  0.10534 ± 0.00000 &  0.08017 ± 0.00000 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### Max error

# %%
full_display_df = create_display_df(col='result.max_err', NAME = "$L_\infty$")
full_display_df = full_display_df.reindex(['GP (Matern)', 'GP (SE)', 'DKL (Matern)', 'DKL (SE)', 'DNNBLR', 'DNN', 'LASSO'])
full_display_df.columns = full_display_df.columns.rename("Dimensionality", level=1)
full_display_df
# Out:
#                        $L_\infty$                                        \
# Dimensionality                 2                  4                  8
# Model
# GP (Matern)     0.00008 ± 0.00000  0.00241 ± 0.00002  0.00368 ± 0.00000
# GP (SE)         0.00034 ± 0.00000  0.01150 ± 0.00037  0.00574 ± 0.00012
# DKL (Matern)    0.00022 ± 0.00000  0.00364 ± 0.00093  0.00370 ± 0.00051
# DKL (SE)        0.03511 ± 0.04943  0.00313 ± 0.00016  0.00551 ± 0.00167
# DNNBLR          0.00027 ± 0.00001  0.00425 ± 0.00018  0.00459 ± 0.00132
# DNN             0.00026 ± 0.00001  0.00831 ± 0.00254  0.00958 ± 0.00284
# LASSO           0.01562 ± 0.00000  0.19826 ± 0.00000  0.19644 ± 0.00000
#
#
# Dimensionality                 12                 20
# Model
# GP (Matern)     0.00358 ± 0.00028  0.00252 ± 0.00000
# GP (SE)         0.00672 ± 0.00000  0.00350 ± 0.00000
# DKL (Matern)    0.00434 ± 0.00004  0.00370 ± 0.00066
# DKL (SE)        0.10132 ± 0.13770  0.00404 ± 0.00065
# DNNBLR          0.00522 ± 0.00162  0.00500 ± 0.00079
# DNN             0.01586 ± 0.00051  0.01379 ± 0.00233
# LASSO           0.19869 ± 0.00000  0.14742 ± 0.00000

# %%
# \label{table:policy-max}
save_table(full_display_df.to_latex(escape=False, bold_rows=True, column_format='lccccc', multicolumn=True, multicolumn_format='c'), 'policy-max')
# Out:
# \begin{tabular}{lccccc}
# \toprule
# {} & \multicolumn{5}{c}{$L_\infty$} \\
# \textbf{Dimensionality} &                 2  &                 4  &                 8  &                 12 &                 20 \\
# \textbf{Model       } &                    &                    &                    &                    &                    \\
# \midrule
# \textbf{GP (Matern) } &  0.00008 ± 0.00000 &  0.00241 ± 0.00002 &  0.00368 ± 0.00000 &  0.00358 ± 0.00028 &  0.00252 ± 0.00000 \\
# \textbf{GP (SE)     } &  0.00034 ± 0.00000 &  0.01150 ± 0.00037 &  0.00574 ± 0.00012 &  0.00672 ± 0.00000 &  0.00350 ± 0.00000 \\
# \textbf{DKL (Matern)} &  0.00022 ± 0.00000 &  0.00364 ± 0.00093 &  0.00370 ± 0.00051 &  0.00434 ± 0.00004 &  0.00370 ± 0.00066 \\
# \textbf{DKL (SE)    } &  0.03511 ± 0.04943 &  0.00313 ± 0.00016 &  0.00551 ± 0.00167 &  0.10132 ± 0.13770 &  0.00404 ± 0.00065 \\
# \textbf{DNNBLR      } &  0.00027 ± 0.00001 &  0.00425 ± 0.00018 &  0.00459 ± 0.00132 &  0.00522 ± 0.00162 &  0.00500 ± 0.00079 \\
# \textbf{DNN         } &  0.00026 ± 0.00001 &  0.00831 ± 0.00254 &  0.00958 ± 0.00284 &  0.01586 ± 0.00051 &  0.01379 ± 0.00233 \\
# \textbf{LASSO       } &  0.01562 ± 0.00000 &  0.19826 ± 0.00000 &  0.19644 ± 0.00000 &  0.19869 ± 0.00000 &  0.14742 ± 0.00000 \\
# \bottomrule
# \end{tabular}
